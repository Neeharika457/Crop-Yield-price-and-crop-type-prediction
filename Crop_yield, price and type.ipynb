# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns

# Set random seed for reproducibility
np.random.seed(42)
random.seed(42)

# -----------------------------------
# 1. Data Generation with Dynamic Yield Trends
# -----------------------------------
# Define districts in South Indian states
states_districts = {
    "Tamil Nadu": ["Ariyalur", "Chennai", "Coimbatore", "Cuddalore", "Dharmapuri", "Dindigul", "Erode", "Kallakurichi",
                   "Kancheepuram", "Kanyakumari", "Karur", "Krishnagiri", "Madurai", "Mayiladuthurai", "Nagapattinam",
                   "Namakkal", "Nilgiris", "Perambalur", "Pudukkottai", "Ramanathapuram", "Ranipet", "Salem", "Sivaganga",
                   "Tenkasi", "Thanjavur", "Theni", "Thoothukudi", "Tiruchirappalli", "Tirunelveli", "Tirupathur", "Tiruppur",
                   "Tiruvallur", "Tiruvannamalai", "Tiruvarur", "Vellore", "Viluppuram", "Virudhunagar", "Chengalpattu"],
    "Karnataka": ["Bagalkot", "Ballari", "Belagavi", "Bengaluru Rural", "Bengaluru Urban", "Bidar", "Chamarajanagar",
                  "Chikkaballapura", "Chikkamagaluru", "Chitradurga", "Dakshina Kannada", "Davangere", "Dharwad", "Gadag",
                  "Hassan", "Haveri", "Kalaburagi", "Kodagu", "Kolar", "Koppal", "Mandya", "Mysuru", "Raichur", "Ramanagara",
                  "Shivamogga", "Tumakuru", "Udupi", "Uttara Kannada", "Vijayanagara", "Vijayapura", "Yadgir"],
    "Andhra Pradesh": ["Alluri Sitharama Raju", "Anakapalli", "Anantapur", "Annamayya", "Bapatla", "Chittoor", "East Godavari",
                       "Eluru", "Guntur", "Kadapa", "Kakinada", "Konaseema", "Krishna", "Kurnool", "Nandyal", "Nellore", "Palnadu",
                       "Parvathipuram Manyam", "Prakasam", "Sri Balaji", "Sri Sathya Sai", "Srikakulam", "Tirupati", "Visakhapatnam",
                       "Vizianagaram", "West Godavari"],
    "Telangana": ["Adilabad", "Bhadradri Kothagudem", "Hyderabad", "Jagtial", "Jangaon", "Jayashankar Bhupalpally", "Jogulamba Gadwal",
                  "Kamareddy", "Karimnagar", "Khammam", "Kumuram Bheem Asifabad", "Mahabubabad", "Mahbubnagar", "Mancherial",
                  "Medak", "Medchal-Malkajgiri", "Mulugu", "Nagarkurnool", "Nalgonda", "Narayanpet", "Nirmal", "Nizamabad",
                  "Peddapalli", "Rajanna Sircilla", "Rangareddy", "Sangareddy", "Siddipet", "Suryapet", "Vikarabad", "Wanaparthy",
                  "Warangal", "Hanumakonda", "Yadadri Bhuvanagiri"],
    "Kerala": ["Alappuzha", "Ernakulam", "Idukki", "Kannur", "Kasaragod", "Kollam", "Kottayam", "Kozhikode", "Malappuram",
               "Palakkad", "Pathanamthitta", "Thiruvananthapuram", "Thrissur", "Wayanad"]
}

# Define crops and harvest months
crops = ["Rice", "Groundnut", "Sugarcane", "Ragi", "Cotton"]
harvest_months = {"Rice": ["Oct"], "Groundnut": ["Nov"], "Sugarcane": ["Jan"], "Ragi": ["Dec"], "Cotton": ["Feb"]}

# Define soil types by district
soil_types_by_state = {"Tamil Nadu": "Red", "Karnataka": "Black", "Andhra Pradesh": "Alluvial", "Telangana": "Red", "Kerala": "Laterite"}
soil_types = {}
for state, districts in states_districts.items():
    base_soil = soil_types_by_state[state]
    for district in districts:
        if state == "Tamil Nadu" and district in ["Thanjavur", "Nagapattinam", "Tiruvarur", "Cuddalore", "Mayiladuthurai"]:
            soil_types[district] = "Alluvial"
        elif state == "Andhra Pradesh" and district in ["East Godavari", "West Godavari", "Krishna", "Guntur", "Bapatla"]:
            soil_types[district] = "Alluvial"
        elif state == "Kerala" or (state == "Karnataka" and district in ["Udupi", "Dakshina Kannada", "Uttara Kannada", "Kodagu"]):
            soil_types[district] = "Laterite"
        elif state == "Karnataka" or (state == "Telangana" and district in ["Adilabad", "Nizamabad", "Karimnagar", "Warangal"]):
            soil_types[district] = "Black"
        elif state == "Andhra Pradesh" and district in ["Anantapur", "Chittoor", "Kadapa", "Kurnool"]:
            soil_types[district] = "Red"
        else:
            soil_types[district] = base_soil

# Crop-soil compatibility
crop_soil_compatibility = {
    "Rice": ["Alluvial", "Clayey"],
    "Groundnut": ["Red", "Sandy Loam"],
    "Sugarcane": ["Alluvial", "Black"],
    "Ragi": ["Red", "Laterite"],
    "Cotton": ["Black", "Red"]
}

# Soil pH and NPK ranges
soil_ph_ranges = {"Alluvial": (6.0, 7.5), "Clayey": (5.8, 7.0), "Red": (5.5, 6.5), "Black": (6.5, 7.8), "Laterite": (5.0, 6.0), "Sandy Loam": (5.5, 6.8)}
npk_base_ranges = {
    "Rice": {"Alluvial": {"N": 120, "P": 30, "K": 200}, "Clayey": {"N": 110, "P": 28, "K": 180}},
    "Groundnut": {"Red": {"N": 50, "P": 40, "K": 120}, "Sandy Loam": {"N": 45, "P": 35, "K": 110}},
    "Sugarcane": {"Alluvial": {"N": 150, "P": 40, "K": 250}, "Black": {"N": 140, "P": 35, "K": 220}},
    "Ragi": {"Red": {"N": 60, "P": 20, "K": 130}, "Laterite": {"N": 55, "P": 18, "K": 120}},
    "Cotton": {"Black": {"N": 80, "P": 40, "K": 150}, "Red": {"N": 70, "P": 35, "K": 140}}
}

# Climate ranges
climate_base_ranges = {
    "Tamil Nadu": {"Temp": (28.0, 32.0), "Rain": (700, 1000), "Hum": (65, 75)},
    "Karnataka": {"Temp": (25.0, 30.0), "Rain": (500, 800), "Hum": (55, 65)},
    "Andhra Pradesh": {"Temp": (29.0, 33.0), "Rain": (600, 900), "Hum": (70, 80)},
    "Telangana": {"Temp": (27.0, 32.0), "Rain": (600, 800), "Hum": (60, 70)},
    "Kerala": {"Temp": (27.0, 30.0), "Rain": (1000, 1500), "Hum": (75, 85)}
}

# Yield ranges
yield_base_ranges = {
    "Rice": {"Alluvial": (4.0, 5.5), "Clayey": (3.5, 5.0)},
    "Groundnut": {"Red": (0.8, 1.4), "Sandy Loam": (0.6, 1.2)},
    "Sugarcane": {"Alluvial": (65, 85), "Black": (60, 80)},
    "Ragi": {"Red": (1.2, 1.8), "Laterite": (1.0, 1.6)},
    "Cotton": {"Black": (1.3, 2.3), "Red": (1.0, 1.8)}
}

# Price ranges
price_base_ranges_2000 = {
    "Rice": (1800, 2200),
    "Groundnut": (2300, 2700),
    "Sugarcane": (1200, 1600),
    "Ragi": (1200, 1500),
    "Cotton": (2800, 3200)
}

# Function to introduce 0.5-1.5% null values
def introduce_nulls(df, columns, null_rate_min=0.005, null_rate_max=0.015):
    for col in columns:
        null_rate = np.random.uniform(null_rate_min, null_rate_max)
        mask = np.random.random(df.shape[0]) < null_rate
        df.loc[mask, col] = np.nan
    return df

# Function to adjust yields with dynamic trends
def adjust_yield(crop, year, base_yield, district):
    drought_years = [2002, 2003, 2012, 2016, 2017]
    recovery_years = [2004, 2013, 2018]

    # Crop-specific growth rates and sensitivities
    growth_rates = {
        "Rice": 1.01 + np.random.uniform(-0.002, 0.002),
        "Groundnut": 1.015 + np.random.uniform(-0.003, 0.003),
        "Sugarcane": 1.012 + np.random.uniform(-0.0025, 0.0025),
        "Ragi": 1.018 + np.random.uniform(-0.004, 0.004),
        "Cotton": 1.02 + np.random.uniform(-0.0035, 0.0035),
    }

    # Crop-specific drought sensitivity
    drought_factors = {
        "Rice": 0.88,
        "Groundnut": 0.75,
        "Sugarcane": 0.92,
        "Ragi": 0.80,
        "Cotton": 0.82,
    }
    recovery_factors = {
        "Rice": 1.05,
        "Groundnut": 1.12,
        "Sugarcane": 1.03,
        "Ragi": 1.09,
        "Cotton": 1.07,
    }

    growth_rate = growth_rates[crop]
    years_since_2000 = year - 2000
    adjusted_yield = base_yield * (growth_rate ** years_since_2000)

    # Apply drought and recovery
    if year in drought_years:
        adjusted_yield *= drought_factors[crop]
    elif year in recovery_years:
        adjusted_yield *= recovery_factors[crop]

    # District-specific adjustments
    if district in ["Chennai", "Bengaluru Urban", "Hyderabad"]:
        adjusted_yield *= 0.9
    elif district in ["Thanjavur", "Nagapattinam", "Tiruvarur", "East Godavari", "West Godavari", "Krishna", "Guntur", "Bapatla"]:
        if crop == "Rice":
            adjusted_yield *= 1.10
    elif district in ["Kurnool", "Kadapa", "Anantapur", "Chittoor"]:
        if crop == "Groundnut":
            adjusted_yield *= 1.15
    elif district in ["Coimbatore", "Erode"]:
        if crop == "Cotton":
            adjusted_yield *= 1.1

    # Add year-to-year variability with crop-specific scaling
    crop_variability = {
        "Rice": 0.06,
        "Groundnut": 0.10,
        "Sugarcane": 0.05,
        "Ragi": 0.09,
        "Cotton": 0.08,
    }
    adjusted_yield *= (1 + np.random.normal(0, crop_variability[crop]))

    return adjusted_yield

# Generate ICRISAT data with dynamic trends
icrisat_data = []
for year in range(2000, 2025):
    for state, districts in states_districts.items():
        for district in districts:
            soil_type = soil_types[district]
            for crop in crops:
                if soil_type not in crop_soil_compatibility[crop]:
                    continue
                for month in harvest_months[crop]:
                    area = np.random.randint(20, 100)
                    yield_range = yield_base_ranges[crop][soil_type]
                    base_yield = np.random.uniform(yield_range[0], yield_range[1])
                    yield_t_ha = adjust_yield(crop, year, base_yield, district)
                    production = round(area * yield_t_ha, 0)
                    icrisat_data.append([state, district, crop, year, month, area, yield_t_ha, production])

icrisat_df = pd.DataFrame(icrisat_data, columns=["State", "District", "Crop", "Year", "Month", "Area_ha", "Yield_t_ha", "Production_t"])
icrisat_df = introduce_nulls(icrisat_df, ["Yield_t_ha", "Production_t"])
icrisat_df.to_csv("icrisat_data_south_india.csv", index=False)

# Generate NASA POWER data
nasa_data = []
for year in range(2000, 2025):
    climate_adjust = {
        state: {
            "Temp": (base["Temp"][0] + (year - 2000) * 0.02, base["Temp"][1] + (year - 2000) * 0.02),
            "Rain": (base["Rain"][0] * (1 - (year - 2000) * 0.0015), base["Rain"][1] * (1 - (year - 2000) * 0.0015)),
            "Hum": (base["Hum"][0] + (year - 2000) * 0.008, base["Hum"][1] + (year - 2000) * 0.008)
        }
        for state, base in climate_base_ranges.items()
    }
    for state, districts in states_districts.items():
        for district in districts:
            soil_type = soil_types[district]
            for crop in crops:
                if soil_type not in crop_soil_compatibility[crop]:
                    continue
                for month in harvest_months[crop]:
                    climate = climate_adjust[state]
                    temp = np.random.uniform(climate["Temp"][0], climate["Temp"][1]) + np.random.normal(0, 0.1)
                    rain = np.random.uniform(climate["Rain"][0], climate["Rain"][1]) + np.random.normal(0, 6)
                    hum = np.random.uniform(climate["Hum"][0], climate["Hum"][1]) + np.random.normal(0, 0.5)
                    nasa_data.append([state, district, crop, year, month, round(temp, 1), round(rain, 0), round(hum, 0)])

nasa_df = pd.DataFrame(nasa_data, columns=["State", "District", "Crop", "Year", "Month", "Temperature_C", "Rainfall_mm", "Humidity_percent"])
nasa_df = introduce_nulls(nasa_df, ["Temperature_C", "Rainfall_mm", "Humidity_percent"])
nasa_df.to_csv("nasa_power_data_south_india.csv", index=False)

# Generate Soil data with low NPK correlation and realistic ranges
soil_data = []
for year in range(2000, 2025):
    for state, districts in states_districts.items():
        for district in districts:
            soil_type = soil_types[district]
            for crop in crops:
                if soil_type not in crop_soil_compatibility[crop]:
                    continue
                ph_range = soil_ph_ranges.get(soil_type, (5.5, 7.0))
                npk_base = npk_base_ranges[crop].get(soil_type, {"N": 80, "P": 30, "K": 150})
                soil_ph = np.random.uniform(ph_range[0], ph_range[1]) + np.random.normal(0, 0.08)
                nitrogen = np.random.normal(npk_base["N"], 7) + np.random.uniform(-12, 12)
                phosphorus = np.random.normal(npk_base["P"], 4) + np.random.uniform(-6, 6)
                potassium = np.random.normal(npk_base["K"], 10) + np.random.uniform(-18, 18)
                nitrogen = np.clip(nitrogen, npk_base["N"] * 0.7, npk_base["N"] * 1.3)
                phosphorus = np.clip(phosphorus, npk_base["P"] * 0.6, npk_base["P"] * 1.4)
                potassium = np.clip(potassium, npk_base["K"] * 0.75, npk_base["K"] * 1.25)
                soil_data.append([state, district, crop, year, soil_type, round(soil_ph, 1), round(nitrogen, 0), round(phosphorus, 0), round(potassium, 0)])

soil_df = pd.DataFrame(soil_data, columns=["State", "District", "Crop", "Year", "Soil_Type", "Soil_pH", "Nitrogen_mg_kg", "Phosphorus_mg_kg", "Potassium_mg_kg"])
soil_df = introduce_nulls(soil_df, ["Soil_pH", "Nitrogen_mg_kg", "Phosphorus_mg_kg", "Potassium_mg_kg"])
soil_df.to_csv("soil_data_south_india.csv", index=False)

# Generate AGMARKNET data
agmarknet_data = []
for year in range(2000, 2025):
    price_adjust = {crop: (base[0] * (1 + (year - 2000) * 0.03), base[1] * (1 + (year - 2000) * 0.03))
                    for crop, base in price_base_ranges_2000.items()}
    for state, districts in states_districts.items():
        for district in districts:
            soil_type = soil_types[district]
            for crop in crops:
                if soil_type not in crop_soil_compatibility[crop]:
                    continue
                for month in harvest_months[crop]:
                    price_range = price_adjust[crop]
                    price = np.random.uniform(price_range[0], price_range[1]) + np.random.normal(0, 12)
                    agmarknet_data.append([state, district, crop, year, month, round(price, 0)])

agmarknet_df = pd.DataFrame(agmarknet_data, columns=["State", "District", "Crop", "Year", "Month", "Market_Price_INR_quintal"])
agmarknet_df = introduce_nulls(agmarknet_df, ["Market_Price_INR_quintal"])
agmarknet_df.to_csv("agmarknet_data_south_india.csv", index=False)

# %%
# -----------------------------------
# 2. Merge Datasets
# -----------------------------------
merged_df = pd.merge(icrisat_df, agmarknet_df, on=["State", "District", "Year", "Month", "Crop"], how="inner")
merged_df = pd.merge(merged_df, nasa_df, on=["State", "District", "Year", "Month"], how="inner")
merged_df = pd.merge(merged_df, soil_df, on=["State", "District", "Year"], how="inner")

merged_df = merged_df.sort_values(by=["State", "District", "Year", "Month", "Crop"])
columns = [
    "State", "District", "Year", "Month", "Crop",
    "Area_ha", "Yield_t_ha", "Production_t",
    "Temperature_C", "Rainfall_mm", "Humidity_percent",
    "Soil_Type", "Soil_pH", "Nitrogen_mg_kg", "Phosphorus_mg_kg", "Potassium_mg_kg",
    "Market_Price_INR_quintal"
]
merged_df = merged_df[columns]

if merged_df.duplicated().sum() > 0:
    print(f"Warning: Found {merged_df.duplicated().sum()} duplicate rows. Dropping duplicates.")
    merged_df = merged_df.drop_duplicates()

print(f"Merged dataset created with {len(merged_df)} rows")
# Out:
# Merged dataset created with 21100 rows

# %%
# -----------------------------------
# 3. Check and Handle Null Values
# -----------------------------------
numerical_columns = merged_df.select_dtypes(include=['float64', 'int64']).columns
print("\nNull value counts before handling:")
print(merged_df.isnull().sum())

for column in numerical_columns:
    median_value = merged_df[column].median()
    merged_df[column] = merged_df[column].fillna(median_value)

print("\nNull value counts after filling:")
print(merged_df.isnull().sum())

# -----------------------------------
# 4. Detect and Replace Outliers
# -----------------------------------
def detect_outliers(df, column, threshold=1.5):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - threshold * IQR
    upper_bound = Q3 + threshold * IQR
    return (df[column] < lower_bound) | (df[column] > upper_bound)

outliers_count = {}
for column in numerical_columns:
    outlier_mask = detect_outliers(merged_df, column)
    outliers_count[column] = outlier_mask.sum()
    print(f"Number of outliers in {column}: {outliers_count[column]}")
    if outliers_count[column] > 0:
        median_value = merged_df[column].median()
        merged_df.loc[outlier_mask, column] = median_value

print("\nAfter replacing outliers with median:")
for column in numerical_columns:
    outlier_mask = detect_outliers(merged_df, column)
    print(f"Number of outliers in {column}: {outlier_mask.sum()}")
# Out:
# Null value counts before handling:
# State                         0
# District                      0
# Year                          0
# Month                         0
# Crop                          0
# Area_ha                       0
# Yield_t_ha                  190
# Production_t                150
# Temperature_C               163
# Rainfall_mm                 227
# Humidity_percent            241
# Soil_Type                     0
# Soil_pH                     153
# Nitrogen_mg_kg              204
# Phosphorus_mg_kg            260
# Potassium_mg_kg             295
# Market_Price_INR_quintal    285
# dtype: int64
#
# Null value counts after filling:
# State                       0
# District                    0
# Year                        0
# Month                       0
# Crop                        0
# Area_ha                     0
# Yield_t_ha                  0
# Production_t                0
# Temperature_C               0
# Rainfall_mm                 0
# Humidity_percent            0
# Soil_Type                   0
# Soil_pH                     0
# Nitrogen_mg_kg              0
# Phosphorus_mg_kg            0
# Potassium_mg_kg             0
# Market_Price_INR_quintal    0
# dtype: int64
# Number of outliers in Year: 0
# Number of outliers in Area_ha: 0
# Number of outliers in Yield_t_ha: 4108
# Number of outliers in Production_t: 3446
# Number of outliers in Temperature_C: 2
# Number of outliers in Rainfall_mm: 316
# Number of outliers in Humidity_percent: 25
# Number of outliers in Soil_pH: 614
# Number of outliers in Nitrogen_mg_kg: 3140
# Number of outliers in Phosphorus_mg_kg: 0
# Number of outliers in Potassium_mg_kg: 2760
# Number of outliers in Market_Price_INR_quintal: 0
#
# After replacing outliers with median:
# Number of outliers in Year: 0
# Number of outliers in Area_ha: 0
# Number of outliers in Yield_t_ha: 927
# Number of outliers in Production_t: 841
# Number of outliers in Temperature_C: 0
# Number of outliers in Rainfall_mm: 16
# Number of outliers in Humidity_percent: 0
# Number of outliers in Soil_pH: 752
# Number of outliers in Nitrogen_mg_kg: 1158
# Number of outliers in Phosphorus_mg_kg: 0
# Number of outliers in Potassium_mg_kg: 1376
# Number of outliers in Market_Price_INR_quintal: 0

# %%
# -----------------------------------
# 5. Feature Engineering
# -----------------------------------
merged_df['Productivity'] = merged_df['Production_t'] / merged_df['Area_ha']
cost_per_ha = 5000
merged_df['Profitability'] = (merged_df['Market_Price_INR_quintal'] * merged_df['Production_t'] / 100) - (cost_per_ha * merged_df['Area_ha'])

# -----------------------------------
# 6. Exploratory Data Analysis (EDA)
# -----------------------------------
print("\nSummary Statistics:")
print(merged_df.describe())

plt.figure(figsize=(10, 8))
sns.heatmap(merged_df[numerical_columns].corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Matrix")
plt.show()

plt.figure(figsize=(12, 6))
for crop in crops:
    crop_data = merged_df[merged_df['Crop'] == crop].groupby('Year')['Yield_t_ha'].mean()
    plt.plot(crop_data.index, crop_data.values, label=crop)
plt.xlabel('Year')
plt.ylabel('Average Yield (t/ha)')
plt.title('Yield Trends Over Time by Crop')
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(10, 6))
state_productivity = merged_df.groupby('State')['Productivity'].mean().sort_values()
sns.barplot(x='Productivity', y=state_productivity.index, data=state_productivity.reset_index())
plt.title('Average Productivity by State')
plt.xlabel('Productivity (t/ha)')
plt.ylabel('State')
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(x='Crop', y='Yield_t_ha', data=merged_df)
plt.title('Yield Distribution by Crop')
plt.xlabel('Crop')
plt.ylabel('Yield (t/ha)')
plt.show()

plt.figure(figsize=(8, 6))
sns.scatterplot(x='Rainfall_mm', y='Yield_t_ha', hue='Crop', data=merged_df)
plt.title('Rainfall vs Yield by Crop')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Yield (t/ha)')
plt.show()

print("\nCorrelation Matrix for Soil Data:")
corr_matrix = merged_df[['Nitrogen_mg_kg', 'Phosphorus_mg_kg', 'Potassium_mg_kg']].corr()
print(corr_matrix)
# Out:
# Summary Statistics:
#                Year       Area_ha    Yield_t_ha  Production_t  Temperature_C  \
# count  21100.000000  21100.000000  21100.000000  21100.000000   21100.000000
# mean    2012.000000     59.398957      1.715456    106.305640      29.873602
# std        7.211273     23.216295      0.478783     52.790216       1.631860
# min     2000.000000     20.000000      0.547233     12.000000      25.000000
# 25%     2006.000000     39.000000      1.398768     68.000000      28.700000
# 50%     2012.000000     59.000000      1.799349    110.000000      30.000000
# 75%     2018.000000     80.000000      1.888761    127.000000      31.200000
# max     2024.000000     99.000000      4.193714    348.000000      33.800000
#
#         Rainfall_mm  Humidity_percent       Soil_pH  Nitrogen_mg_kg  \
# count  21100.000000      21100.000000  21100.000000    21100.000000
# mean     743.885877         67.985071      6.208450       65.136825
# std      105.509207          5.494799      0.509865       16.960338
# min      477.000000         54.000000      5.000000       35.000000
# 25%      671.000000         64.000000      5.800000       55.000000
# 50%      738.000000         68.000000      6.200000       66.000000
# 75%      807.000000         72.000000      6.400000       71.000000
# max     1030.000000         84.000000      7.500000      125.000000
#
#        Phosphorus_mg_kg  Potassium_mg_kg  Market_Price_INR_quintal  \
# count      21100.000000     21100.000000              21100.000000
# mean          32.699668       136.953602               2958.092607
# std            9.389012        22.468031               1075.898882
# min           11.000000        90.000000               1164.000000
# 25%           26.000000       123.000000               1988.000000
# 50%           34.000000       138.000000               2935.000000
# 75%           40.000000       145.000000               3814.500000
# max           56.000000       210.000000               5505.000000
#
#        Productivity  Profitability
# count  21100.000000   21100.000000
# mean       1.887978 -293827.784851
# std        0.933217  115138.363749
# min        0.552083 -493441.300000
# 25%        1.333333 -393945.890000
# 50%        1.670588 -292210.400000
# 75%        2.098120 -193777.980000
# max        7.800000  -95743.800000
# Correlation Matrix for Soil Data:
#                   Nitrogen_mg_kg  Phosphorus_mg_kg  Potassium_mg_kg
# Nitrogen_mg_kg          1.000000         -0.008624         0.506189
# Phosphorus_mg_kg       -0.008624          1.000000         0.011091
# Potassium_mg_kg         0.506189          0.011091         1.000000

# %%
# -----------------------------------
# 7. Save the Final Dataset
# -----------------------------------
merged_df.to_csv("merged_data.csv", index=False)
print(f"\nFinal dataset saved: merged_data.csv with {len(merged_df)} rows")
# Out:
# Final dataset saved: merged_data.csv with 21100 rows

# %%
merged_df.isnull().sum()
# Out:
# State                       0
# District                    0
# Year                        0
# Month                       0
# Crop                        0
# Area_ha                     0
# Yield_t_ha                  0
# Production_t                0
# Temperature_C               0
# Rainfall_mm                 0
# Humidity_percent            0
# Soil_Type                   0
# Soil_pH                     0
# Nitrogen_mg_kg              0
# Phosphorus_mg_kg            0
# Potassium_mg_kg             0
# Market_Price_INR_quintal    0
# Productivity                0
# Profitability               0
# dtype: int64

# %%
#one hot encoding
df_encoded1 = pd.get_dummies(merged_df, columns=['State', 'District', 'Crop', 'Month', 'Soil_Type'], drop_first=True)
df_encoded1.head()
# Out:
#       Year  Area_ha  Yield_t_ha  Production_t  Temperature_C  Rainfall_mm  \
# 431   2000       36    1.799349         110.0           30.1        686.0
# 432   2000       36    1.799349         110.0           30.1        686.0
# 429   2000       81    1.799349         110.0           30.9        896.0
# 430   2000       81    1.799349         110.0           30.9        896.0
# 1275  2001       59    1.799349         110.0           32.7        806.0
#
#       Humidity_percent  Soil_pH  Nitrogen_mg_kg  Phosphorus_mg_kg  ...  \
# 431               79.0      7.4            66.0              28.0  ...
# 432               79.0      7.3            66.0              49.0  ...
# 429               78.0      7.4            66.0              28.0  ...
# 430               78.0      7.3            66.0              49.0  ...
# 1275              72.0      6.7           124.0              25.0  ...
#
#       Crop_Ragi  Crop_Rice  Crop_Sugarcane  Month_Feb  Month_Jan  Month_Nov  \
# 431       False       True           False      False       True      False
# 432       False      False            True      False       True      False
# 429       False       True           False      False      False      False
# 430       False      False            True      False      False      False
# 1275      False       True           False      False       True      False
#
#       Month_Oct  Soil_Type_Black  Soil_Type_Laterite  Soil_Type_Red
# 431       False            False               False          False
# 432       False            False               False          False
# 429        True            False               False          False
# 430        True            False               False          False
# 1275      False            False               False          False
#
# [5 rows x 170 columns]

# %%
#Standard scaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_scaled = df_encoded1.copy()
df_scaled[numerical_columns] = scaler.fit_transform(df_encoded1[numerical_columns])
df_scaled.head()
# Out:
#           Year   Area_ha  Yield_t_ha  Production_t  Temperature_C  \
# 431  -1.664101 -1.007892    0.175226      0.069984       0.138740
# 432  -1.664101 -1.007892    0.175226      0.069984       0.138740
# 429  -1.664101  0.930448    0.175226      0.069984       0.628989
# 430  -1.664101  0.930448    0.175226      0.069984       0.628989
# 1275 -1.525426 -0.017185    0.175226      0.069984       1.732051
#
#       Rainfall_mm  Humidity_percent   Soil_pH  Nitrogen_mg_kg  \
# 431     -0.548646          2.004657  2.337046        0.050895
# 432     -0.548646          2.004657  2.140911        0.050895
# 429      1.441748          1.822663  2.337046        0.050895
# 430      1.441748          1.822663  2.140911        0.050895
# 1275     0.588722          0.730695  0.964101        3.470719
#
#       Phosphorus_mg_kg  ...  Crop_Ragi  Crop_Rice  Crop_Sugarcane  Month_Feb  \
# 431          -0.500562  ...      False       True           False      False
# 432           1.736148  ...      False      False            True      False
# 429          -0.500562  ...      False       True           False      False
# 430           1.736148  ...      False      False            True      False
# 1275         -0.820092  ...      False       True           False      False
#
#       Month_Jan  Month_Nov  Month_Oct  Soil_Type_Black  Soil_Type_Laterite  \
# 431        True      False      False            False               False
# 432        True      False      False            False               False
# 429       False      False       True            False               False
# 430       False      False       True            False               False
# 1275       True      False      False            False               False
#
#       Soil_Type_Red
# 431           False
# 432           False
# 429           False
# 430           False
# 1275          False
#
# [5 rows x 170 columns]

# %%
numerical_columns
# Out:
# Index(['Year', 'Area_ha', 'Yield_t_ha', 'Production_t', 'Temperature_C',
#        'Rainfall_mm', 'Humidity_percent', 'Soil_pH', 'Nitrogen_mg_kg',
#        'Phosphorus_mg_kg', 'Potassium_mg_kg', 'Market_Price_INR_quintal'],
#       dtype='object')

# %%
#what and what are correlated like yield_t_ha is correlated with production_t_ha
import pandas as pd

# Calculate the correlation matrix
matrix = merged_df.corr(numeric_only=True).abs()

# Create a list to store correlated groups
correlated_groups = []

# Set threshold for "high correlation"
threshold = 0.7

# Track visited pairs to avoid duplicates
visited = set()

# Iterate through the upper triangle of the correlation matrix
for i in range(len(matrix.columns)):
    for j in range(i + 1, len(matrix.columns)):
        col1 = matrix.columns[i]
        col2 = matrix.columns[j]
        corr_value = matrix.iloc[i, j]
        if corr_value > threshold:
            # Find if either col is already part of an existing group
            added = False
            for group in correlated_groups:
                if col1 in group or col2 in group:
                    group.update([col1, col2])
                    added = True
                    break
            if not added:
                correlated_groups.append(set([col1, col2]))

# Convert sets to sorted lists for readability
correlated_groups = [sorted(list(group)) for group in correlated_groups]

# Display results
for group in correlated_groups:
    print(group)
# Out:
# ['Area_ha', 'Profitability']

# %%
# columns_to_drop = [group[0] for group in correlated_groups]

# # Step 5: Drop those columns from the dataset
# reduced_df = df_scaled.drop(columns=columns_to_drop)

# # Optional: print dropped columns
# print("Dropped columns:", columns_to_drop)

# %%
# 1. Data Summary
print("Data Summary:")
print(merged_df.info())

# 2. Descriptive Statistics
print("\nDescriptive Statistics:")
print(merged_df.describe())

# 3. Missing Values Check
missing_values = merged_df.isnull().mean() * 100
print("\nMissing Values (%):")
print(missing_values)
# Out:
# Data Summary:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21100 entries, 431 to 21078
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   State                     21100 non-null  object
#  1   District                  21100 non-null  object
#  2   Year                      21100 non-null  int64
#  3   Month                     21100 non-null  object
#  4   Crop                      21100 non-null  object
#  5   Area_ha                   21100 non-null  int64
#  6   Yield_t_ha                21100 non-null  float64
#  7   Production_t              21100 non-null  float64
#  8   Temperature_C             21100 non-null  float64
#  9   Rainfall_mm               21100 non-null  float64
#  10  Humidity_percent          21100 non-null  float64
#  11  Soil_Type                 21100 non-null  object
#  12  Soil_pH                   21100 non-null  float64
#  13  Nitrogen_mg_kg            21100 non-null  float64
#  14  Phosphorus_mg_kg          21100 non-null  float64
#  15  Potassium_mg_kg           21100 non-null  float64
#  16  Market_Price_INR_quintal  21100 non-null  float64
#  17  Productivity              21100 non-null  float64
#  18  Profitability             21100 non-null  float64
# dtypes: float64(12), int64(2), object(5)
# memory usage: 3.2+ MB
# None
#
# Descriptive Statistics:
#                Year       Area_ha    Yield_t_ha  Production_t  Temperature_C  \
# count  21100.000000  21100.000000  21100.000000  21100.000000   21100.000000
# mean    2012.000000     59.398957      1.715456    106.305640      29.873602
# std        7.211273     23.216295      0.478783     52.790216       1.631860
# min     2000.000000     20.000000      0.547233     12.000000      25.000000
# 25%     2006.000000     39.000000      1.398768     68.000000      28.700000
# 50%     2012.000000     59.000000      1.799349    110.000000      30.000000
# 75%     2018.000000     80.000000      1.888761    127.000000      31.200000
# max     2024.000000     99.000000      4.193714    348.000000      33.800000
#
#         Rainfall_mm  Humidity_percent       Soil_pH  Nitrogen_mg_kg  \
# count  21100.000000      21100.000000  21100.000000    21100.000000
# mean     743.885877         67.985071      6.208450       65.136825
# std      105.509207          5.494799      0.509865       16.960338
# min      477.000000         54.000000      5.000000       35.000000
# 25%      671.000000         64.000000      5.800000       55.000000
# 50%      738.000000         68.000000      6.200000       66.000000
# 75%      807.000000         72.000000      6.400000       71.000000
# max     1030.000000         84.000000      7.500000      125.000000
#
#        Phosphorus_mg_kg  Potassium_mg_kg  Market_Price_INR_quintal  \
# count      21100.000000     21100.000000              21100.000000
# mean          32.699668       136.953602               2958.092607
# std            9.389012        22.468031               1075.898882
# min           11.000000        90.000000               1164.000000
# 25%           26.000000       123.000000               1988.000000
# 50%           34.000000       138.000000               2935.000000
# 75%           40.000000       145.000000               3814.500000
# max           56.000000       210.000000               5505.000000
#
#        Productivity  Profitability
# count  21100.000000   21100.000000
# mean       1.887978 -293827.784851
# std        0.933217  115138.363749
# min        0.552083 -493441.300000
# 25%        1.333333 -393945.890000
# 50%        1.670588 -292210.400000
# 75%        2.098120 -193777.980000
# max        7.800000  -95743.800000
#
# Missing Values (%):
# State                       0.0
# District                    0.0
# Year                        0.0
# Month                       0.0
# Crop                        0.0
# Area_ha                     0.0
# Yield_t_ha                  0.0
# Production_t                0.0
# Temperature_C               0.0
# Rainfall_mm                 0.0
# Humidity_percent            0.0
# Soil_Type                   0.0
# Soil_pH                     0.0
# Nitrogen_mg_kg              0.0
# Phosphorus_mg_kg            0.0
# Potassium_mg_kg             0.0
# Market_Price_INR_quintal    0.0
# Productivity                0.0
# Profitability               0.0
# dtype: float64

# %%
# 4. Target Variable Distributions
# Crop Yield
plt.figure(figsize=(12, 6))
sns.histplot(merged_df['Yield_t_ha'], kde=True, bins=20, color='skyblue')
plt.title('Crop Yield Distribution')
plt.xlabel('Yield (t/ha)')
plt.ylabel('Frequency')
plt.show()

# Crop Price
plt.figure(figsize=(12, 6))
sns.histplot(merged_df['Market_Price_INR_quintal'], kde=True, bins=20, color='orange')
plt.title('Crop Price Distribution')
plt.xlabel('Price (INR/quintal)')
plt.ylabel('Frequency')
plt.show()

# Crop Type
# Since 'Crop' is one-hot encoded, choose one encoded column to visualize
plt.figure(figsize=(12, 6))
sns.countplot(x='Crop_Rice', data=df_encoded1, palette='Set2')  # Example: Visualizing Rice crop
plt.title('Rice Crop Distribution')  # Update title accordingly
plt.xlabel('Rice Crop')  # Update x-axis label accordingly
plt.ylabel('Frequency')
plt.show()
# Out:
# <ipython-input-14-82b8c1f6dd56>:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Crop_Rice', data=df_encoded1, palette='Set2')  # Example: Visualizing Rice crop

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(x='Soil_pH', y='Yield_t_ha', hue='Crop_Rice', data=df_encoded1, palette='Set2')  # Use 'Crop_Rice' or another encoded column
plt.title('Soil pH vs Crop Yield')
plt.xlabel('Soil pH')
plt.ylabel('Yield (t/ha)')
plt.legend(title='Crop_Rice')
plt.show()

plt.figure(figsize=(12, 6))
sns.scatterplot(x='Temperature_C', y='Yield_t_ha', hue='Crop_Rice', data=df_encoded1, palette='Set2')  # Use 'Crop_Rice' or another encoded column
plt.title('Temperature vs Crop Yield')
plt.show()

# %%
#for how many rows crop_rice is true
df_encoded1['Crop_Rice'].value_counts()
# Out:
# Crop_Rice
# False    19750
# True      1350
# Name: count, dtype: int64

# %%
#give crop_rice=true 5 rows
df_encoded1[df_encoded1['Crop_Rice'] == True].head()
# Out:
#       Year  Area_ha  Yield_t_ha  Production_t  Temperature_C  Rainfall_mm  \
# 431   2000       36    1.799349         110.0           30.1        686.0
# 429   2000       81    1.799349         110.0           30.9        896.0
# 1275  2001       59    1.799349         110.0           32.7        806.0
# 1273  2001       66    1.799349         287.0           30.9        757.0
# 2119  2002       28    1.799349         110.0           32.0        743.0
#
#       Humidity_percent  Soil_pH  Nitrogen_mg_kg  Phosphorus_mg_kg  ...  \
# 431               79.0      7.4            66.0              28.0  ...
# 429               78.0      7.4            66.0              28.0  ...
# 1275              72.0      6.7           124.0              25.0  ...
# 1273              73.0      6.7           124.0              25.0  ...
# 2119              68.0      7.0           104.0              31.0  ...
#
#       Crop_Ragi  Crop_Rice  Crop_Sugarcane  Month_Feb  Month_Jan  Month_Nov  \
# 431       False       True           False      False       True      False
# 429       False       True           False      False      False      False
# 1275      False       True           False      False       True      False
# 1273      False       True           False      False      False      False
# 2119      False       True           False      False       True      False
#
#       Month_Oct  Soil_Type_Black  Soil_Type_Laterite  Soil_Type_Red
# 431       False            False               False          False
# 429        True            False               False          False
# 1275      False            False               False          False
# 1273       True            False               False          False
# 2119      False            False               False          False
#
# [5 rows x 170 columns]

# %%
#give crop = rice from df_filled 5 rows
merged_df[merged_df['Crop'] == 'Rice'].head()
# Out:
#                State               District  Year Month  Crop  Area_ha  \
# 431   Andhra Pradesh  Alluri Sitharama Raju  2000   Jan  Rice       36
# 429   Andhra Pradesh  Alluri Sitharama Raju  2000   Oct  Rice       81
# 1275  Andhra Pradesh  Alluri Sitharama Raju  2001   Jan  Rice       59
# 1273  Andhra Pradesh  Alluri Sitharama Raju  2001   Oct  Rice       66
# 2119  Andhra Pradesh  Alluri Sitharama Raju  2002   Jan  Rice       28
#
#       Yield_t_ha  Production_t  Temperature_C  Rainfall_mm  Humidity_percent  \
# 431     1.799349         110.0           30.1        686.0              79.0
# 429     1.799349         110.0           30.9        896.0              78.0
# 1275    1.799349         110.0           32.7        806.0              72.0
# 1273    1.799349         287.0           30.9        757.0              73.0
# 2119    1.799349         110.0           32.0        743.0              68.0
#
#      Soil_Type  Soil_pH  Nitrogen_mg_kg  Phosphorus_mg_kg  Potassium_mg_kg  \
# 431   Alluvial      7.4            66.0              28.0            198.0
# 429   Alluvial      7.4            66.0              28.0            198.0
# 1275  Alluvial      6.7           124.0              25.0            138.0
# 1273  Alluvial      6.7           124.0              25.0            138.0
# 2119  Alluvial      7.0           104.0              31.0            138.0
#
#       Market_Price_INR_quintal  Productivity  Profitability
# 431                     1325.0      3.055556      -178542.5
# 429                     2075.0      1.358025      -402717.5
# 1275                    1492.0      1.864407      -293358.8
# 1273                    1990.0      4.348485      -324288.7
# 2119                    1560.0      3.928571      -138284.0

# %% [markdown]
# Crop_Rice = False means that the crop there is rice (from the above 2 code cells)

# %%
sns.histplot(merged_df['Yield_t_ha'], kde=True)
plt.title("Distribution of Crop Yield")
plt.show()

sns.histplot(merged_df['Market_Price_INR_quintal'], kde=True) # Changed 'crop_price' to 'Market_Price_INR_quintal'
plt.title("Distribution of Crop Price")
plt.show()

merged_df['Crop'].value_counts().plot(kind='bar')  # Changed 'crop_type' to 'Crop'
plt.title("Crop Type Distribution")
plt.show()

# %%
top_districts = merged_df.groupby('District')['Market_Price_INR_quintal'].median().nlargest(20).index
df_top = merged_df[merged_df['District'].isin(top_districts)]

plt.figure(figsize=(14, 6))
sns.boxplot(x='District', y='Market_Price_INR_quintal', data=df_top)
plt.title("Top 20 Districts by Median Crop Price")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier, GradientBoostingRegressor, GradientBoostingClassifier
from sklearn.linear_model import LinearRegression, Ridge, Lasso, LogisticRegression
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, classification_report, confusion_matrix
from sklearn.pipeline import Pipeline
import matplotlib.pyplot as plt
import seaborn as sns
import logging
import joblib
import os
from time import time
from sklearn.metrics import roc_auc_score
import warnings

# Setup logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# Suppress specific warnings
warnings.filterwarnings("ignore", category=UserWarning)

# -----------------------------------
# 1. Data Loading and Validation
# -----------------------------------
def load_and_validate_data(file_path):
    if not os.path.exists(file_path):
        raise FileNotFoundError(f"{file_path} not found")
    df = pd.read_csv(file_path)
    required_columns = ['Crop', 'Yield_t_ha', 'Market_Price_INR_quintal', 'Year', 'Area_ha', 'Temperature_C',
                       'Rainfall_mm', 'Humidity_percent', 'Soil_pH', 'Nitrogen_mg_kg', 'Phosphorus_mg_kg',
                       'Potassium_mg_kg', 'State', 'District', 'Month', 'Soil_Type']
    missing_cols = [col for col in required_columns if col not in df.columns]
    if missing_cols:
        raise ValueError(f"Missing columns: {missing_cols}")
    logger.info("Data loaded and validated successfully")
    return df

# Load data
df_encoded = load_and_validate_data("merged_data.csv")

# -----------------------------------
# 2. Data Preprocessing
# -----------------------------------
numerical_features = ['Year', 'Area_ha', 'Temperature_C', 'Rainfall_mm', 'Humidity_percent', 'Soil_pH',
                      'Nitrogen_mg_kg', 'Phosphorus_mg_kg', 'Potassium_mg_kg']
categorical_features = ['State', 'District', 'Month', 'Soil_Type']

# Impute missing values
imputer_num = SimpleImputer(strategy='median')
imputer_cat = SimpleImputer(strategy='most_frequent')
df_encoded[numerical_features] = imputer_num.fit_transform(df_encoded[numerical_features])
df_encoded[categorical_features] = imputer_cat.fit_transform(df_encoded[categorical_features])

# One-hot encode categorical features
df_encoded = pd.get_dummies(df_encoded, columns=categorical_features, dummy_na=False)

# Encode target variable 'Crop'
label_encoder = LabelEncoder()
df_encoded['Crop_encoded'] = label_encoder.fit_transform(df_encoded['Crop'])

# Define features and targets
X = df_encoded.drop(['Crop', 'Yield_t_ha', 'Market_Price_INR_quintal', 'Crop_encoded', 'Productivity', 'Profitability'],
                   axis=1, errors='ignore')
y_yield = df_encoded['Yield_t_ha']
y_crop = df_encoded['Crop_encoded']
y_price = df_encoded['Market_Price_INR_quintal']

# Split data
X_train, X_test, y_yield_train, y_yield_test, y_crop_train, y_crop_test, y_price_train, y_price_test = train_test_split(
    X, y_yield, y_crop, y_price, test_size=0.2, random_state=42)

# Selective scaling using ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_features),
        ('cat', 'passthrough', [col for col in X.columns if col not in numerical_features])
    ])
X_train = preprocessor.fit_transform(X_train)
X_test = preprocessor.transform(X_test)

# -----------------------------------
# 3. Model Training and Evaluation
# -----------------------------------
def train_and_evaluate_regression(model, X_train, y_train, X_test, y_test, model_name='Regression Model'):
    start_time = time()
    model.fit(X_train, y_train)
    end_time = time()
    training_time = end_time - start_time
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test, y_pred)
    mae = np.mean(np.abs(y_test - y_pred))
    cv_scores = cross_val_score(model, X_train, y_train, cv=5, scoring='r2')
    logger.info(f"{model_name} - Training Time: {training_time:.2f} seconds")
    logger.info(f"{model_name} - MSE: {mse:.2f}, RMSE: {rmse:.2f}, R-squared: {r2:.2f}, MAE: {mae:.2f}")
    logger.info(f"{model_name} - CV R-squared: {cv_scores.mean():.2f} ± {cv_scores.std():.2f}")
    return {'model': model, 'predictions': y_pred, 'MSE': mse, 'RMSE': rmse, 'R2': r2, 'MAE': mae, 'CV_R2': cv_scores.mean()}

def train_and_evaluate_classification(model, X_train, y_train, X_test, y_test, model_name='Classification Model'):
    start_time = time()
    model.fit(X_train, y_train)
    end_time = time()
    training_time = end_time - start_time
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    report = classification_report(y_test, y_pred, output_dict=True, zero_division=0)
    precision = report['weighted avg']['precision']
    recall = report['weighted avg']['recall']
    f1 = report['weighted avg']['f1-score']
    auc_roc = None
    try:
        auc_roc = roc_auc_score(y_test, model.predict_proba(X_test), multi_class='ovr')
    except (AttributeError, ValueError):
        logger.warning(f"{model_name} - AUC-ROC not computed (proba unavailable or binary issue)")
    logger.info(f"{model_name} - Training Time: {training_time:.2f} seconds")
    logger.info(f"{model_name} - Accuracy: {accuracy:.2f}, Precision: {precision:.2f}, Recall: {recall:.2f}, F1: {f1:.2f}, AUC-ROC: {auc_roc if auc_roc else 'N/A'}")
    return {'model': model, 'predictions': y_pred, 'accuracy': accuracy, 'precision': precision, 'recall': recall, 'f1': f1, 'auc_roc': auc_roc}

# Regression Models
regression_models = {
    'Linear Regression': LinearRegression(),
    'Ridge Regression': Ridge(alpha=1.0),
    'Lasso Regression': Lasso(alpha=1.0),
    'Decision Tree Regressor': DecisionTreeRegressor(random_state=42),
    'Random Forest Regressor': RandomForestRegressor(n_estimators=100, random_state=42, n_jobs=-1),
    'Gradient Boosting Regressor': GradientBoostingRegressor(n_estimators=100, random_state=42)
}

# Classification Models
classification_models = {
    'Logistic Regression': Pipeline([('scaler', StandardScaler()), ('clf', LogisticRegression(random_state=42))]),
    'Decision Tree Classifier': DecisionTreeClassifier(random_state=42),
    'Random Forest Classifier': RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1),
    'Gradient Boosting Classifier': GradientBoostingClassifier(n_estimators=100, random_state=42),
    'K-Nearest Neighbors Classifier': KNeighborsClassifier(),
    'Gaussian Naive Bayes': GaussianNB(),
    'Linear Discriminant Analysis': LinearDiscriminantAnalysis()
}

# Store results
regression_results = {}
classification_results = {}

# Yield Prediction
logger.info("--- Yield Prediction (Regression) ---")
for name, model in regression_models.items():
    regression_results[name] = train_and_evaluate_regression(model, X_train, y_yield_train, X_test, y_yield_test, name)

# Crop Type Prediction
logger.info("\n--- Crop Type Prediction (Classification) ---")
for name, model in classification_models.items():
    classification_results[name] = train_and_evaluate_classification(model, X_train, y_crop_train, X_test, y_crop_test, name)

# Price Prediction
logger.info("\n--- Price Prediction (Regression) ---")
for name, model in regression_models.items():
    regression_results[name] = train_and_evaluate_regression(model, X_train, y_price_train, X_test, y_price_test, name)

# -----------------------------------
# 4. Results Visualization
# -----------------------------------
# Yield Prediction
plt.figure(figsize=(8, 5))
for name, result in regression_results.items():
    plt.bar(name, result['R2'], label=f"{name} (R2)")
plt.title('Yield Prediction Performance')
plt.ylabel('R-squared')
plt.xticks(rotation=45, ha="right")
plt.legend()
plt.tight_layout()
plt.show()

# Crop Type Prediction
plt.figure(figsize=(8, 5))
for name, result in classification_results.items():
    plt.bar(name, result['accuracy'], label=f"{name} (Accuracy)")
plt.title('Crop Type Prediction Performance')
plt.ylabel('Accuracy')
plt.xticks(rotation=45, ha="right")
plt.legend()
plt.tight_layout()
plt.show()

# Confusion Matrix for Best Classifier
best_clf = classification_results['Random Forest Classifier']['model']
y_pred = best_clf.predict(X_test)
cm = confusion_matrix(y_crop_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix (Random Forest Classifier)')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# Price Prediction
plt.figure(figsize=(8, 5))
for name, result in regression_results.items():
    plt.bar(name, result['R2'], label=f"{name} (R2)")
plt.title('Price Prediction Performance')
plt.ylabel('R-squared')
plt.xticks(rotation=45, ha="right")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# import pandas as pd
# import numpy as np
# from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
# from sklearn.preprocessing import StandardScaler, LabelEncoder
# from sklearn.impute import SimpleImputer
# from sklearn.compose import ColumnTransformer
# from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier, GradientBoostingRegressor
# from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, precision_recall_fscore_support, confusion_matrix
# import matplotlib.pyplot as plt
# import seaborn as sns
# import logging
# import joblib
# import os
# from time import time
# import warnings

# # Setup logging
# logging.basicConfig(level=logging.INFO)
# logger = logging.getLogger(__name__)

# # Suppress specific warnings
# warnings.filterwarnings("ignore", category=UserWarning)

# # -----------------------------------
# # 1. Data Loading and Validation
# # -----------------------------------
# def load_and_validate_data(file_path):
#     if not os.path.exists(file_path):
#         raise FileNotFoundError(f"{file_path} not found")
#     df = pd.read_csv(file_path)
#     required_columns = ['Crop', 'Yield_t_ha', 'Market_Price_INR_quintal', 'Year', 'Area_ha', 'Temperature_C',
#                        'Rainfall_mm', 'Humidity_percent', 'Soil_pH', 'Nitrogen_mg_kg', 'Phosphorus_mg_kg',
#                        'Potassium_mg_kg', 'State', 'District', 'Month', 'Soil_Type']
#     missing_cols = [col for col in required_columns if col not in df.columns]
#     if missing_cols:
#         raise ValueError(f"Missing columns: {missing_cols}")
#     logger.info("Data loaded and validated successfully")
#     return df

# # Load data
# df_encoded = load_and_validate_data("merged_data.csv")

# # -----------------------------------
# # 2. Data Preprocessing
# # -----------------------------------
# numerical_features = ['Year', 'Area_ha', 'Temperature_C', 'Rainfall_mm', 'Humidity_percent', 'Soil_pH',
#                       'Nitrogen_mg_kg', 'Phosphorus_mg_kg', 'Potassium_mg_kg']
# categorical_features = ['State', 'District', 'Month', 'Soil_Type']

# # Impute missing values
# imputer_num = SimpleImputer(strategy='median')
# imputer_cat = SimpleImputer(strategy='most_frequent')
# df_encoded[numerical_features] = imputer_num.fit_transform(df_encoded[numerical_features])
# df_encoded[categorical_features] = imputer_cat.fit_transform(df_encoded[categorical_features])

# # One-hot encode categorical features
# df_encoded = pd.get_dummies(df_encoded, columns=categorical_features, dummy_na=False)

# # Encode target variable 'Crop'
# label_encoder = LabelEncoder()
# df_encoded['Crop_encoded'] = label_encoder.fit_transform(df_encoded['Crop'])

# # Define features and targets
# X = df_encoded.drop(['Crop', 'Yield_t_ha', 'Market_Price_INR_quintal', 'Crop_encoded', 'Productivity', 'Profitability'],
#                    axis=1, errors='ignore')
# y_yield = df_encoded['Yield_t_ha']
# y_crop = df_encoded['Crop_encoded']
# y_price = df_encoded['Market_Price_INR_quintal']

# # Split data
# X_train, X_test, y_yield_train, y_yield_test, y_crop_train, y_crop_test, y_price_train, y_price_test = train_test_split(
#     X, y_yield, y_crop, y_price, test_size=0.2, random_state=42)

# # Selective scaling using ColumnTransformer
# preprocessor = ColumnTransformer(
#     transformers=[
#         ('num', StandardScaler(), numerical_features),
#         ('cat', 'passthrough', [col for col in X.columns if col not in numerical_features])
#     ])
# X_train = preprocessor.fit_transform(X_train)
# X_test = preprocessor.transform(X_test)

# # -----------------------------------
# # 3. Model Training and Evaluation
# # -----------------------------------
# def train_and_evaluate_regression(model, X_train, y_train, X_test, y_test, model_name='Regression Model'):
#     start_time = time()
#     model.fit(X_train, y_train)
#     end_time = time()
#     training_time = end_time - start_time
#     y_pred = model.predict(X_test)
#     mse = mean_squared_error(y_test, y_pred)
#     rmse = np.sqrt(mse)
#     r2 = r2_score(y_test, y_pred)
#     mae = np.mean(np.abs(y_test - y_pred))
#     cv_scores = cross_val_score(model, X_train, y_train, cv=5, scoring='r2')
#     logger.info(f"{model_name} - Training Time: {training_time:.2f} seconds")
#     logger.info(f"{model_name} - MSE: {mse:.2f}, RMSE: {rmse:.2f}, R-squared: {r2:.2f}, MAE: {mae:.2f}")
#     logger.info(f"{model_name} - CV R-squared: {cv_scores.mean():.2f} ± {cv_scores.std():.2f}")
#     return {'model': model, 'predictions': y_pred, 'MSE': mse, 'RMSE': rmse, 'R2': r2, 'MAE': mae, 'CV_R2': cv_scores.mean()}

# def train_and_evaluate_classification(model, X_train, y_train, X_test, y_test, model_name='Classification Model'):
#     start_time = time()
#     model.fit(X_train, y_train)
#     end_time = time()
#     training_time = end_time - start_time
#     y_pred = model.predict(X_test)
#     accuracy = accuracy_score(y_test, y_pred)
#     precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred, average='weighted')
#     auc_roc = None
#     try:
#         auc_roc = roc_auc_score(y_test, model.predict_proba(X_test), multi_class='ovr')
#     except (AttributeError, ValueError):
#         logger.warning(f"{model_name} - AUC-ROC not computed (proba unavailable or binary issue)")
#     logger.info(f"{model_name} - Training Time: {training_time:.2f} seconds")
#     logger.info(f"{model_name} - Accuracy: {accuracy:.2f}, Precision: {precision:.2f}, Recall: {recall:.2f}, F1: {f1:.2f}, AUC-ROC: {auc_roc if auc_roc else 'N/A'}")
#     return {'model': model, 'predictions': y_pred, 'accuracy': accuracy, 'precision': precision, 'recall': recall, 'f1': f1, 'auc_roc': auc_roc}

# # Models
# regression_models = {
#     'Linear Regression': LinearRegression(),
#     'Ridge Regression': Ridge(alpha=1.0),
#     'Lasso Regression': Lasso(alpha=1.0),
#     # 'Polynomial Regression (degree 2)': Pipeline([('poly', PolynomialFeatures(degree=2)), ('linear', LinearRegression())]),
#     'Decision Tree Regressor': DecisionTreeRegressor(random_state=42),
#     'Random Forest Regressor': RandomForestRegressor(n_estimators=100, random_state=42),
#     'Gradient Boosting Regressor': GradientBoostingRegressor(n_estimators=100, random_state=42),
#     # 'Neural Network Regressor': MLPRegressor(hidden_layer_sizes=(64, 64), random_state=42),
#     # 'SVR': SVR()  # Support Vector Regression
# }
# classification_models = {
#     'Logistic Regression': Pipeline([('scaler', StandardScaler()), ('clf', LogisticRegression(random_state=42))]),
#     'Decision Tree Classifier': DecisionTreeClassifier(random_state=42),
#     'Random Forest Classifier': RandomForestClassifier(n_estimators=100, random_state=42),
#     'Gradient Boosting Classifier': GradientBoostingClassifier(n_estimators=100, random_state=42),
#     # 'Neural Network Classifier': MLPClassifier(hidden_layer_sizes=(64, 64), random_state=42),
#     # 'SVM Classifier': SVC(probability=True, random_state=42),  # Enable probability for AUC-ROC
#     'K-Nearest Neighbors Classifier': KNeighborsClassifier(),
#     'Gaussian Naive Bayes': GaussianNB(),
#     'Linear Discriminant Analysis': LinearDiscriminantAnalysis(),
#     # 'Quadratic Discriminant Analysis': QuadraticDiscriminantAnalysis(),
# }

# # Store results
# regression_results = {}
# classification_results = {}

# # Yield Prediction
# logger.info("--- Yield Prediction (Regression) ---")
# for name, model in regression_models.items():
#     regression_results[name] = train_and_evaluate_regression(model, X_train, y_yield_train, X_test, y_yield_test, name)

# # Crop Type Prediction
# logger.info("\n--- Crop Type Prediction (Classification) ---")
# for name, model in classification_models.items():
#     classification_results[name] = train_and_evaluate_classification(model, X_train, y_crop_train, X_test, y_crop_test, name)

# # Price Prediction
# logger.info("\n--- Price Prediction (Regression) ---")
# for name, model in regression_models.items():
#     regression_results[name] = train_and_evaluate_regression(model, X_train, y_price_train, X_test, y_price_test, name)

# # -----------------------------------
# # 4. Results Visualization
# # -----------------------------------
# # Yield Prediction
# plt.figure(figsize=(8, 5))
# for name, result in regression_results.items():
#     plt.bar(name, result['R2'], label=f"{name} (R2)")
# plt.title('Yield Prediction Performance')
# plt.ylabel('R-squared')
# plt.xticks(rotation=45, ha="right")
# plt.legend()
# plt.tight_layout()
# plt.savefig('yield_performance.png')
# plt.close()

# # Crop Type Prediction with Confusion Matrix
# plt.figure(figsize=(8, 5))
# for name, result in classification_results.items():
#     plt.bar(name, result['accuracy'], label=f"{name} (Accuracy)")
# plt.title('Crop Type Prediction Performance')
# plt.ylabel('Accuracy')
# plt.xticks(rotation=45, ha="right")
# plt.legend()
# plt.tight_layout()
# plt.savefig('crop_performance.png')
# plt.close()

# # Confusion Matrix for Best Classifier
# best_clf = classification_results['Random Forest Classifier']['model']
# y_pred = best_clf.predict(X_test)
# cm = confusion_matrix(y_crop_test, y_pred)
# plt.figure(figsize=(8, 6))
# sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
# plt.title('Confusion Matrix (Random Forest Classifier)')
# plt.xlabel('Predicted')
# plt.ylabel('Actual')
# plt.savefig('confusion_matrix.png')
# plt.close()

# # Price Prediction
# plt.figure(figsize=(8, 5))
# for name, result in regression_results.items():
#     plt.bar(name, result['R2'], label=f"{name} (R2)")
# plt.title('Price Prediction Performance')
# plt.ylabel('R-squared')
# plt.xticks(rotation=45, ha="right")
# plt.legend()
# plt.tight_layout()
# plt.savefig('price_performance.png')
# plt.close()

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.3.0-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.15.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.1)
# Downloading optuna-4.3.0-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.6/386.6 kB 8.3 MB/s eta 0:00:00
# Downloading alembic-1.15.2-py3-none-any.whl (231 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.9/231.9 kB 19.2 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, alembic, optuna
# Successfully installed alembic-1.15.2 colorlog-6.9.0 optuna-4.3.0

# %%
# Finalized ML Pipeline with Best Models for Yield, Price, and Crop Type

from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import HistGradientBoostingRegressor, HistGradientBoostingClassifier
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import r2_score, accuracy_score
import optuna
import logging

logger = logging.getLogger()

# Split
data_split = train_test_split(X, y_yield, y_price, y_crop, test_size=0.2, random_state=42)
X_train, X_test, y_yield_train, y_yield_test, y_price_train, y_price_test, y_crop_train, y_crop_test = data_split

# ---------------------------- OPTUNA OBJECTIVES ----------------------------

# Random Forest for Yield

def objective_rf_yield(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'max_depth': trial.suggest_int('max_depth', 10, 50, log=True),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 20),
        'max_features': trial.suggest_categorical('max_features', ['sqrt', 'log2', None]),
        'random_state': 42,
        'n_jobs': -1
    }
    model = RandomForestRegressor(**params)
    return cross_val_score(model, X_train, y_yield_train, cv=3, scoring='r2').mean()

# Random Forest for Price

def objective_rf_price(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'max_depth': trial.suggest_int('max_depth', 10, 50, log=True),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 20),
        'max_features': trial.suggest_categorical('max_features', ['sqrt', 'log2', None]),
        'random_state': 42,
        'n_jobs': -1
    }
    model = RandomForestRegressor(**params)
    return cross_val_score(model, X_train, y_price_train, cv=3, scoring='r2').mean()

# Decision Tree for Crop Classification

def objective_dt_crop(trial):
    params = {
        'max_depth': trial.suggest_int('max_depth', 5, 30, log=True),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 20),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 10),
        'criterion': trial.suggest_categorical('criterion', ['gini', 'entropy']),
        'random_state': 42
    }
    model = DecisionTreeClassifier(**params)
    return cross_val_score(model, X_train, y_crop_train, cv=3, scoring='accuracy').mean()

# ---------------------------- OPTIMIZE MODELS ----------------------------

# Yield Model
study_rf_yield = optuna.create_study(direction='maximize')
study_rf_yield.optimize(objective_rf_yield, n_trials=50)
best_rf_params_yield = study_rf_yield.best_params
yield_model = RandomForestRegressor(**best_rf_params_yield, random_state=42, n_jobs=-1)
yield_model.fit(X_train, y_yield_train)
yield_pred = yield_model.predict(X_test)
yield_r2 = r2_score(y_yield_test, yield_pred)
logger.info(f"Best RF Parameters (Yield): {best_rf_params_yield}")
logger.info(f"Tuned Yield R2: {yield_r2:.2f}")

# Price Model
study_rf_price = optuna.create_study(direction='maximize')
study_rf_price.optimize(objective_rf_price, n_trials=50)
best_rf_params_price = study_rf_price.best_params
price_model = RandomForestRegressor(**best_rf_params_price, random_state=42, n_jobs=-1)
price_model.fit(X_train, y_price_train)
price_pred = price_model.predict(X_test)
price_r2 = r2_score(y_price_test, price_pred)
logger.info(f"Best RF Parameters (Price): {best_rf_params_price}")
logger.info(f"Tuned Price R2: {price_r2:.2f}")

# Crop Model
study_dt_crop = optuna.create_study(direction='maximize')
study_dt_crop.optimize(objective_dt_crop, n_trials=50)
best_dt_params = study_dt_crop.best_params
crop_model = DecisionTreeClassifier(**best_dt_params, random_state=42)
crop_model.fit(X_train, y_crop_train)
crop_pred = crop_model.predict(X_test)
crop_accuracy = accuracy_score(y_crop_test, crop_pred)
logger.info(f"Best DT Parameters (Crop): {best_dt_params}")
logger.info(f"Tuned Crop Accuracy: {crop_accuracy:.2f}")
# Out:
# [I 2025-05-02 08:54:43,060] A new study created in memory with name: no-name-815c214f-659e-48a8-800c-7a65b92e5cb5
# [I 2025-05-02 08:54:52,963] Trial 0 finished with value: 0.7518781361552793 and parameters: {'n_estimators': 57, 'max_depth': 40, 'min_samples_split': 10, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.7518781361552793.
# [I 2025-05-02 08:56:33,337] Trial 1 finished with value: 0.9366963722890583 and parameters: {'n_estimators': 189, 'max_depth': 12, 'min_samples_split': 2, 'max_features': None}. Best is trial 1 with value: 0.9366963722890583.
# [I 2025-05-02 08:56:37,120] Trial 2 finished with value: 0.5261248198485516 and parameters: {'n_estimators': 100, 'max_depth': 14, 'min_samples_split': 6, 'max_features': 'log2'}. Best is trial 1 with value: 0.9366963722890583.
# [I 2025-05-02 08:58:06,178] Trial 3 finished with value: 0.9353395849935238 and parameters: {'n_estimators': 172, 'max_depth': 41, 'min_samples_split': 15, 'max_features': None}. Best is trial 1 with value: 0.9366963722890583.
# [I 2025-05-02 08:58:11,193] Trial 4 finished with value: 0.4578286433070941 and parameters: {'n_estimators': 164, 'max_depth': 11, 'min_samples_split': 16, 'max_features': 'log2'}. Best is trial 1 with value: 0.9366963722890583.
# [I 2025-05-02 08:58:22,734] Trial 5 finished with value: 0.7373468538712211 and parameters: {'n_estimators': 132, 'max_depth': 38, 'min_samples_split': 17, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.9366963722890583.
# [I 2025-05-02 08:58:33,215] Trial 6 finished with value: 0.606709306014324 and parameters: {'n_estimators': 193, 'max_depth': 13, 'min_samples_split': 16, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.9366963722890583.
# [I 2025-05-02 08:58:36,601] Trial 7 finished with value: 0.44951958098931594 and parameters: {'n_estimators': 107, 'max_depth': 11, 'min_samples_split': 17, 'max_features': 'log2'}. Best is trial 1 with value: 0.9366963722890583.
# [I 2025-05-02 08:58:55,060] Trial 8 finished with value: 0.7138368552006304 and parameters: {'n_estimators': 232, 'max_depth': 25, 'min_samples_split': 20, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.9366963722890583.
# [I 2025-05-02 08:59:00,954] Trial 9 finished with value: 0.5464271893336072 and parameters: {'n_estimators': 144, 'max_depth': 16, 'min_samples_split': 20, 'max_features': 'log2'}. Best is trial 1 with value: 0.9366963722890583.
# [I 2025-05-02 09:01:59,060] Trial 10 finished with value: 0.9515236712900303 and parameters: {'n_estimators': 277, 'max_depth': 21, 'min_samples_split': 2, 'max_features': None}. Best is trial 10 with value: 0.9515236712900303.
# [I 2025-05-02 09:05:12,442] Trial 11 finished with value: 0.9507802468122257 and parameters: {'n_estimators': 296, 'max_depth': 22, 'min_samples_split': 3, 'max_features': None}. Best is trial 10 with value: 0.9515236712900303.
# [I 2025-05-02 09:08:23,890] Trial 12 finished with value: 0.9516696500788754 and parameters: {'n_estimators': 297, 'max_depth': 23, 'min_samples_split': 2, 'max_features': None}. Best is trial 12 with value: 0.9516696500788754.
# [I 2025-05-02 09:11:07,218] Trial 13 finished with value: 0.9449971613037507 and parameters: {'n_estimators': 292, 'max_depth': 28, 'min_samples_split': 7, 'max_features': None}. Best is trial 12 with value: 0.9516696500788754.
# [I 2025-05-02 09:13:32,405] Trial 14 finished with value: 0.9471637984424832 and parameters: {'n_estimators': 249, 'max_depth': 18, 'min_samples_split': 5, 'max_features': None}. Best is trial 12 with value: 0.9516696500788754.
# [I 2025-05-02 09:15:50,726] Trial 15 finished with value: 0.9425527532253051 and parameters: {'n_estimators': 253, 'max_depth': 30, 'min_samples_split': 9, 'max_features': None}. Best is trial 12 with value: 0.9516696500788754.
# [I 2025-05-02 09:18:35,977] Trial 16 finished with value: 0.9488582204542382 and parameters: {'n_estimators': 267, 'max_depth': 19, 'min_samples_split': 4, 'max_features': None}. Best is trial 12 with value: 0.9516696500788754.
# [I 2025-05-02 09:20:29,220] Trial 17 finished with value: 0.9376399581246219 and parameters: {'n_estimators': 224, 'max_depth': 50, 'min_samples_split': 13, 'max_features': None}. Best is trial 12 with value: 0.9516696500788754.
# [I 2025-05-02 09:22:27,619] Trial 18 finished with value: 0.943754216018409 and parameters: {'n_estimators': 216, 'max_depth': 22, 'min_samples_split': 8, 'max_features': None}. Best is trial 12 with value: 0.9516696500788754.
# [I 2025-05-02 09:25:25,028] Trial 19 finished with value: 0.9503210958840826 and parameters: {'n_estimators': 275, 'max_depth': 28, 'min_samples_split': 3, 'max_features': None}. Best is trial 12 with value: 0.9516696500788754.
# [I 2025-05-02 09:27:55,569] Trial 20 finished with value: 0.93939669963956 and parameters: {'n_estimators': 300, 'max_depth': 16, 'min_samples_split': 11, 'max_features': None}. Best is trial 12 with value: 0.9516696500788754.
# [I 2025-05-02 09:30:59,620] Trial 21 finished with value: 0.9515692760518206 and parameters: {'n_estimators': 283, 'max_depth': 21, 'min_samples_split': 2, 'max_features': None}. Best is trial 12 with value: 0.9516696500788754.
# [I 2025-05-02 09:33:51,191] Trial 22 finished with value: 0.9513531673376925 and parameters: {'n_estimators': 271, 'max_depth': 19, 'min_samples_split': 2, 'max_features': None}. Best is trial 12 with value: 0.9516696500788754.
# [I 2025-05-02 09:36:07,691] Trial 23 finished with value: 0.9475824961481718 and parameters: {'n_estimators': 240, 'max_depth': 23, 'min_samples_split': 5, 'max_features': None}. Best is trial 12 with value: 0.9516696500788754.
# [I 2025-05-02 09:38:56,802] Trial 24 finished with value: 0.9487489704483689 and parameters: {'n_estimators': 276, 'max_depth': 33, 'min_samples_split': 4, 'max_features': None}. Best is trial 12 with value: 0.9516696500788754.
# [I 2025-05-02 09:41:51,523] Trial 25 finished with value: 0.9514647579082613 and parameters: {'n_estimators': 258, 'max_depth': 26, 'min_samples_split': 2, 'max_features': None}. Best is trial 12 with value: 0.9516696500788754.
# [I 2025-05-02 09:43:46,575] Trial 26 finished with value: 0.9456411471311954 and parameters: {'n_estimators': 206, 'max_depth': 17, 'min_samples_split': 6, 'max_features': None}. Best is trial 12 with value: 0.9516696500788754.
# [I 2025-05-02 09:46:37,937] Trial 27 finished with value: 0.9486631707485097 and parameters: {'n_estimators': 284, 'max_depth': 20, 'min_samples_split': 4, 'max_features': None}. Best is trial 12 with value: 0.9516696500788754.
# [I 2025-05-02 09:46:56,180] Trial 28 finished with value: 0.6969591332587595 and parameters: {'n_estimators': 244, 'max_depth': 33, 'min_samples_split': 8, 'max_features': 'log2'}. Best is trial 12 with value: 0.9516696500788754.
# [I 2025-05-02 09:47:19,359] Trial 29 finished with value: 0.7182844923056464 and parameters: {'n_estimators': 300, 'max_depth': 24, 'min_samples_split': 13, 'max_features': 'sqrt'}. Best is trial 12 with value: 0.9516696500788754.
# [I 2025-05-02 09:47:23,641] Trial 30 finished with value: 0.6445946916220165 and parameters: {'n_estimators': 52, 'max_depth': 15, 'min_samples_split': 3, 'max_features': 'sqrt'}. Best is trial 12 with value: 0.9516696500788754.
# [I 2025-05-02 09:50:19,835] Trial 31 finished with value: 0.951498134965807 and parameters: {'n_estimators': 265, 'max_depth': 26, 'min_samples_split': 2, 'max_features': None}. Best is trial 12 with value: 0.9516696500788754.
# [I 2025-05-02 09:53:11,227] Trial 32 finished with value: 0.9515479986200777 and parameters: {'n_estimators': 263, 'max_depth': 20, 'min_samples_split': 2, 'max_features': None}. Best is trial 12 with value: 0.9516696500788754.
# [I 2025-05-02 09:56:03,501] Trial 33 finished with value: 0.9472778112270653 and parameters: {'n_estimators': 282, 'max_depth': 20, 'min_samples_split': 5, 'max_features': None}. Best is trial 12 with value: 0.9516696500788754.
# [I 2025-05-02 09:56:52,630] Trial 34 finished with value: 0.9519063204415659 and parameters: {'n_estimators': 71, 'max_depth': 21, 'min_samples_split': 2, 'max_features': None}. Best is trial 34 with value: 0.9519063204415659.
# [I 2025-05-02 09:57:44,551] Trial 35 finished with value: 0.9429808584626572 and parameters: {'n_estimators': 99, 'max_depth': 14, 'min_samples_split': 6, 'max_features': None}. Best is trial 34 with value: 0.9519063204415659.
# [I 2025-05-02 09:58:40,899] Trial 36 finished with value: 0.9508280246728971 and parameters: {'n_estimators': 63, 'max_depth': 18, 'min_samples_split': 3, 'max_features': None}. Best is trial 34 with value: 0.9519063204415659.
# [I 2025-05-02 09:58:45,461] Trial 37 finished with value: 0.6443278979397903 and parameters: {'n_estimators': 73, 'max_depth': 23, 'min_samples_split': 4, 'max_features': 'log2'}. Best is trial 34 with value: 0.9519063204415659.
# [I 2025-05-02 10:00:26,796] Trial 38 finished with value: 0.9394137307000048 and parameters: {'n_estimators': 185, 'max_depth': 13, 'min_samples_split': 6, 'max_features': None}. Best is trial 34 with value: 0.9519063204415659.
# [I 2025-05-02 10:01:01,963] Trial 39 finished with value: 0.7804778450011514 and parameters: {'n_estimators': 151, 'max_depth': 31, 'min_samples_split': 2, 'max_features': 'sqrt'}. Best is trial 34 with value: 0.9519063204415659.
# [I 2025-05-02 10:01:05,846] Trial 40 finished with value: 0.4316649136479517 and parameters: {'n_estimators': 120, 'max_depth': 10, 'min_samples_split': 3, 'max_features': 'log2'}. Best is trial 34 with value: 0.9519063204415659.
# [I 2025-05-02 10:04:38,760] Trial 41 finished with value: 0.9515437071069114 and parameters: {'n_estimators': 281, 'max_depth': 21, 'min_samples_split': 2, 'max_features': None}. Best is trial 34 with value: 0.9519063204415659.
# [I 2025-05-02 10:07:47,895] Trial 42 finished with value: 0.9515579733944655 and parameters: {'n_estimators': 288, 'max_depth': 20, 'min_samples_split': 2, 'max_features': None}. Best is trial 34 with value: 0.9519063204415659.
# [I 2025-05-02 10:08:38,609] Trial 43 finished with value: 0.9481991624454882 and parameters: {'n_estimators': 88, 'max_depth': 17, 'min_samples_split': 4, 'max_features': None}. Best is trial 34 with value: 0.9519063204415659.
# [I 2025-05-02 10:11:10,985] Trial 44 finished with value: 0.9472577873148349 and parameters: {'n_estimators': 259, 'max_depth': 24, 'min_samples_split': 5, 'max_features': None}. Best is trial 34 with value: 0.9519063204415659.
# [I 2025-05-02 10:14:16,324] Trial 45 finished with value: 0.9504956953243934 and parameters: {'n_estimators': 289, 'max_depth': 20, 'min_samples_split': 3, 'max_features': None}. Best is trial 34 with value: 0.9519063204415659.
# [I 2025-05-02 10:15:48,674] Trial 46 finished with value: 0.9449560556136284 and parameters: {'n_estimators': 164, 'max_depth': 27, 'min_samples_split': 7, 'max_features': None}. Best is trial 34 with value: 0.9519063204415659.
# [I 2025-05-02 10:16:08,528] Trial 47 finished with value: 0.7035073111184651 and parameters: {'n_estimators': 235, 'max_depth': 18, 'min_samples_split': 2, 'max_features': 'sqrt'}. Best is trial 34 with value: 0.9519063204415659.
# [I 2025-05-02 10:17:30,637] Trial 48 finished with value: 0.9508660451783795 and parameters: {'n_estimators': 128, 'max_depth': 21, 'min_samples_split': 3, 'max_features': None}. Best is trial 34 with value: 0.9519063204415659.
# [I 2025-05-02 10:17:42,324] Trial 49 finished with value: 0.5564319200571529 and parameters: {'n_estimators': 224, 'max_depth': 16, 'min_samples_split': 11, 'max_features': 'log2'}. Best is trial 34 with value: 0.9519063204415659.
# [I 2025-05-02 10:17:56,078] A new study created in memory with name: no-name-e450487f-e132-4b31-b108-9d5bf14f106c
# [I 2025-05-02 10:18:08,013] Trial 0 finished with value: 0.8807823409624586 and parameters: {'n_estimators': 213, 'max_depth': 21, 'min_samples_split': 16, 'max_features': 'log2'}. Best is trial 0 with value: 0.8807823409624586.
# [I 2025-05-02 10:18:23,979] Trial 1 finished with value: 0.8884356818573359 and parameters: {'n_estimators': 296, 'max_depth': 13, 'min_samples_split': 9, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.8884356818573359.
# [I 2025-05-02 10:18:36,748] Trial 2 finished with value: 0.9000994208894688 and parameters: {'n_estimators': 220, 'max_depth': 14, 'min_samples_split': 11, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.9000994208894688.
# [I 2025-05-02 10:19:05,224] Trial 3 finished with value: 0.9367504235947972 and parameters: {'n_estimators': 269, 'max_depth': 20, 'min_samples_split': 11, 'max_features': 'sqrt'}. Best is trial 3 with value: 0.9367504235947972.
# [I 2025-05-02 10:19:18,293] Trial 4 finished with value: 0.9309900446746469 and parameters: {'n_estimators': 77, 'max_depth': 31, 'min_samples_split': 3, 'max_features': 'log2'}. Best is trial 3 with value: 0.9367504235947972.
# [I 2025-05-02 10:19:30,017] Trial 5 finished with value: 0.9363249267087103 and parameters: {'n_estimators': 142, 'max_depth': 21, 'min_samples_split': 13, 'max_features': 'sqrt'}. Best is trial 3 with value: 0.9367504235947972.
# [I 2025-05-02 10:19:38,163] Trial 6 finished with value: 0.9449511651435809 and parameters: {'n_estimators': 77, 'max_depth': 24, 'min_samples_split': 6, 'max_features': 'sqrt'}. Best is trial 6 with value: 0.9449511651435809.
# [I 2025-05-02 10:20:02,424] Trial 7 finished with value: 0.9497202669765439 and parameters: {'n_estimators': 259, 'max_depth': 30, 'min_samples_split': 14, 'max_features': 'sqrt'}. Best is trial 7 with value: 0.9497202669765439.
# [I 2025-05-02 10:20:11,765] Trial 8 finished with value: 0.8998524738890372 and parameters: {'n_estimators': 154, 'max_depth': 24, 'min_samples_split': 11, 'max_features': 'log2'}. Best is trial 7 with value: 0.9497202669765439.
# [I 2025-05-02 10:20:30,758] Trial 9 finished with value: 0.9588361235992892 and parameters: {'n_estimators': 146, 'max_depth': 45, 'min_samples_split': 5, 'max_features': 'sqrt'}. Best is trial 9 with value: 0.9588361235992892.
# [I 2025-05-02 10:21:54,564] Trial 10 finished with value: 0.976905521246076 and parameters: {'n_estimators': 122, 'max_depth': 48, 'min_samples_split': 20, 'max_features': None}. Best is trial 10 with value: 0.976905521246076.
# [I 2025-05-02 10:23:16,555] Trial 11 finished with value: 0.9770551671905296 and parameters: {'n_estimators': 120, 'max_depth': 46, 'min_samples_split': 19, 'max_features': None}. Best is trial 11 with value: 0.9770551671905296.
# [I 2025-05-02 10:24:31,616] Trial 12 finished with value: 0.976912609868427 and parameters: {'n_estimators': 111, 'max_depth': 48, 'min_samples_split': 20, 'max_features': None}. Best is trial 11 with value: 0.9770551671905296.
# [I 2025-05-02 10:25:42,567] Trial 13 finished with value: 0.9768992104842298 and parameters: {'n_estimators': 106, 'max_depth': 38, 'min_samples_split': 20, 'max_features': None}. Best is trial 11 with value: 0.9770551671905296.
# [I 2025-05-02 10:26:17,589] Trial 14 finished with value: 0.9769557843413785 and parameters: {'n_estimators': 50, 'max_depth': 38, 'min_samples_split': 18, 'max_features': None}. Best is trial 11 with value: 0.9770551671905296.
# [I 2025-05-02 10:26:55,903] Trial 15 finished with value: 0.9771489431571899 and parameters: {'n_estimators': 55, 'max_depth': 35, 'min_samples_split': 17, 'max_features': None}. Best is trial 15 with value: 0.9771489431571899.
# [I 2025-05-02 10:28:16,519] Trial 16 finished with value: 0.9723091449393013 and parameters: {'n_estimators': 185, 'max_depth': 10, 'min_samples_split': 17, 'max_features': None}. Best is trial 15 with value: 0.9771489431571899.
# [I 2025-05-02 10:29:11,264] Trial 17 finished with value: 0.9775803800299905 and parameters: {'n_estimators': 78, 'max_depth': 33, 'min_samples_split': 15, 'max_features': None}. Best is trial 17 with value: 0.9775803800299905.
# [I 2025-05-02 10:29:47,397] Trial 18 finished with value: 0.9774160923939306 and parameters: {'n_estimators': 50, 'max_depth': 32, 'min_samples_split': 15, 'max_features': None}. Best is trial 17 with value: 0.9775803800299905.
# [I 2025-05-02 10:30:45,590] Trial 19 finished with value: 0.9777841236661619 and parameters: {'n_estimators': 82, 'max_depth': 28, 'min_samples_split': 14, 'max_features': None}. Best is trial 19 with value: 0.9777841236661619.
# [I 2025-05-02 10:31:51,787] Trial 20 finished with value: 0.9788991269195298 and parameters: {'n_estimators': 86, 'max_depth': 26, 'min_samples_split': 8, 'max_features': None}. Best is trial 20 with value: 0.9788991269195298.
# [I 2025-05-02 10:32:58,329] Trial 21 finished with value: 0.9789029986317598 and parameters: {'n_estimators': 86, 'max_depth': 27, 'min_samples_split': 8, 'max_features': None}. Best is trial 21 with value: 0.9789029986317598.
# [I 2025-05-02 10:34:08,364] Trial 22 finished with value: 0.9789321604501783 and parameters: {'n_estimators': 90, 'max_depth': 27, 'min_samples_split': 8, 'max_features': None}. Best is trial 22 with value: 0.9789321604501783.
# [I 2025-05-02 10:35:15,027] Trial 23 finished with value: 0.9777843201814445 and parameters: {'n_estimators': 97, 'max_depth': 17, 'min_samples_split': 8, 'max_features': None}. Best is trial 22 with value: 0.9789321604501783.
# [I 2025-05-02 10:37:27,358] Trial 24 finished with value: 0.978978103819602 and parameters: {'n_estimators': 171, 'max_depth': 25, 'min_samples_split': 8, 'max_features': None}. Best is trial 24 with value: 0.978978103819602.
# [I 2025-05-02 10:39:39,351] Trial 25 finished with value: 0.9793990604188693 and parameters: {'n_estimators': 176, 'max_depth': 19, 'min_samples_split': 5, 'max_features': None}. Best is trial 25 with value: 0.9793990604188693.
# [I 2025-05-02 10:39:50,318] Trial 26 finished with value: 0.8673628921471502 and parameters: {'n_estimators': 190, 'max_depth': 18, 'min_samples_split': 5, 'max_features': 'log2'}. Best is trial 25 with value: 0.9793990604188693.
# [I 2025-05-02 10:41:45,859] Trial 27 finished with value: 0.9799357514623095 and parameters: {'n_estimators': 166, 'max_depth': 16, 'min_samples_split': 3, 'max_features': None}. Best is trial 27 with value: 0.9799357514623095.
# [I 2025-05-02 10:43:41,265] Trial 28 finished with value: 0.9793796158755216 and parameters: {'n_estimators': 171, 'max_depth': 15, 'min_samples_split': 3, 'max_features': None}. Best is trial 27 with value: 0.9799357514623095.
# [I 2025-05-02 10:43:52,520] Trial 29 finished with value: 0.8072821942570574 and parameters: {'n_estimators': 213, 'max_depth': 14, 'min_samples_split': 2, 'max_features': 'log2'}. Best is trial 27 with value: 0.9799357514623095.
# [I 2025-05-02 10:46:37,503] Trial 30 finished with value: 0.9799945897870526 and parameters: {'n_estimators': 235, 'max_depth': 16, 'min_samples_split': 3, 'max_features': None}. Best is trial 30 with value: 0.9799945897870526.
# [I 2025-05-02 10:49:18,993] Trial 31 finished with value: 0.9799906868804168 and parameters: {'n_estimators': 227, 'max_depth': 16, 'min_samples_split': 3, 'max_features': None}. Best is trial 30 with value: 0.9799945897870526.
# [I 2025-05-02 10:51:27,840] Trial 32 finished with value: 0.9762935081254783 and parameters: {'n_estimators': 236, 'max_depth': 12, 'min_samples_split': 4, 'max_features': None}. Best is trial 30 with value: 0.9799945897870526.
# [I 2025-05-02 10:53:57,497] Trial 33 finished with value: 0.9810408475489731 and parameters: {'n_estimators': 199, 'max_depth': 17, 'min_samples_split': 2, 'max_features': None}. Best is trial 33 with value: 0.9810408475489731.
# [I 2025-05-02 10:56:46,501] Trial 34 finished with value: 0.9806042602184221 and parameters: {'n_estimators': 238, 'max_depth': 16, 'min_samples_split': 2, 'max_features': None}. Best is trial 33 with value: 0.9810408475489731.
# [I 2025-05-02 10:58:55,490] Trial 35 finished with value: 0.9775538380640174 and parameters: {'n_estimators': 234, 'max_depth': 12, 'min_samples_split': 2, 'max_features': None}. Best is trial 33 with value: 0.9810408475489731.
# [I 2025-05-02 10:59:09,643] Trial 36 finished with value: 0.791310939009618 and parameters: {'n_estimators': 297, 'max_depth': 13, 'min_samples_split': 2, 'max_features': 'log2'}. Best is trial 33 with value: 0.9810408475489731.
# [I 2025-05-02 11:02:14,437] Trial 37 finished with value: 0.9783887647094073 and parameters: {'n_estimators': 268, 'max_depth': 17, 'min_samples_split': 6, 'max_features': None}. Best is trial 33 with value: 0.9810408475489731.
# [I 2025-05-02 11:02:33,516] Trial 38 finished with value: 0.9449503057736447 and parameters: {'n_estimators': 197, 'max_depth': 22, 'min_samples_split': 4, 'max_features': 'sqrt'}. Best is trial 33 with value: 0.9810408475489731.
# [I 2025-05-02 11:05:09,692] Trial 39 finished with value: 0.9774900875202093 and parameters: {'n_estimators': 248, 'max_depth': 15, 'min_samples_split': 6, 'max_features': None}. Best is trial 33 with value: 0.9810408475489731.
# [I 2025-05-02 11:05:22,901] Trial 40 finished with value: 0.8844847027888356 and parameters: {'n_estimators': 202, 'max_depth': 20, 'min_samples_split': 4, 'max_features': 'log2'}. Best is trial 33 with value: 0.9810408475489731.
# [I 2025-05-02 11:07:49,679] Trial 41 finished with value: 0.9794184688127918 and parameters: {'n_estimators': 222, 'max_depth': 15, 'min_samples_split': 3, 'max_features': None}. Best is trial 33 with value: 0.9810408475489731.
# [I 2025-05-02 11:10:15,398] Trial 42 finished with value: 0.97996953651445 and parameters: {'n_estimators': 211, 'max_depth': 16, 'min_samples_split': 3, 'max_features': None}. Best is trial 33 with value: 0.9810408475489731.
# [I 2025-05-02 11:10:41,614] Trial 43 finished with value: 0.9478137086410608 and parameters: {'n_estimators': 230, 'max_depth': 22, 'min_samples_split': 2, 'max_features': 'sqrt'}. Best is trial 33 with value: 0.9810408475489731.
# [I 2025-05-02 11:14:12,243] Trial 44 finished with value: 0.9807569715622526 and parameters: {'n_estimators': 280, 'max_depth': 18, 'min_samples_split': 3, 'max_features': None}. Best is trial 33 with value: 0.9810408475489731.
# [I 2025-05-02 11:17:34,371] Trial 45 finished with value: 0.9791876644830426 and parameters: {'n_estimators': 280, 'max_depth': 18, 'min_samples_split': 5, 'max_features': None}. Best is trial 33 with value: 0.9810408475489731.
# [I 2025-05-02 11:20:36,760] Trial 46 finished with value: 0.979194298026082 and parameters: {'n_estimators': 247, 'max_depth': 20, 'min_samples_split': 6, 'max_features': None}. Best is trial 33 with value: 0.9810408475489731.
# [I 2025-05-02 11:20:54,899] Trial 47 finished with value: 0.8913465288500696 and parameters: {'n_estimators': 279, 'max_depth': 13, 'min_samples_split': 4, 'max_features': 'sqrt'}. Best is trial 33 with value: 0.9810408475489731.
# [I 2025-05-02 11:23:21,927] Trial 48 finished with value: 0.9766017146052217 and parameters: {'n_estimators': 250, 'max_depth': 14, 'min_samples_split': 7, 'max_features': None}. Best is trial 33 with value: 0.9810408475489731.
# [I 2025-05-02 11:25:28,344] Trial 49 finished with value: 0.9735158494371895 and parameters: {'n_estimators': 266, 'max_depth': 11, 'min_samples_split': 12, 'max_features': None}. Best is trial 33 with value: 0.9810408475489731.
# [I 2025-05-02 11:26:04,399] A new study created in memory with name: no-name-3e4781f8-c59b-4893-98df-344fc44577a8
# [I 2025-05-02 11:26:05,079] Trial 0 finished with value: 0.9396327014218009 and parameters: {'max_depth': 11, 'min_samples_split': 20, 'min_samples_leaf': 2, 'criterion': 'entropy'}. Best is trial 0 with value: 0.9396327014218009.
# [I 2025-05-02 11:26:05,600] Trial 1 finished with value: 0.928376777251185 and parameters: {'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 0 with value: 0.9396327014218009.
# [I 2025-05-02 11:26:06,308] Trial 2 finished with value: 0.9385663507109004 and parameters: {'max_depth': 13, 'min_samples_split': 14, 'min_samples_leaf': 10, 'criterion': 'gini'}. Best is trial 0 with value: 0.9396327014218009.
# [I 2025-05-02 11:26:07,164] Trial 3 finished with value: 0.9406990521327014 and parameters: {'max_depth': 29, 'min_samples_split': 2, 'min_samples_leaf': 8, 'criterion': 'gini'}. Best is trial 3 with value: 0.9406990521327014.
# [I 2025-05-02 11:26:08,207] Trial 4 finished with value: 0.938329383886256 and parameters: {'max_depth': 15, 'min_samples_split': 7, 'min_samples_leaf': 7, 'criterion': 'entropy'}. Best is trial 3 with value: 0.9406990521327014.
# [I 2025-05-02 11:26:09,135] Trial 5 finished with value: 0.9339454976303319 and parameters: {'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 9, 'criterion': 'entropy'}. Best is trial 3 with value: 0.9406990521327014.
# [I 2025-05-02 11:26:09,895] Trial 6 finished with value: 0.9376777251184834 and parameters: {'max_depth': 26, 'min_samples_split': 16, 'min_samples_leaf': 9, 'criterion': 'entropy'}. Best is trial 3 with value: 0.9406990521327014.
# [I 2025-05-02 11:26:10,446] Trial 7 finished with value: 0.9292061611374407 and parameters: {'max_depth': 7, 'min_samples_split': 12, 'min_samples_leaf': 3, 'criterion': 'entropy'}. Best is trial 3 with value: 0.9406990521327014.
# [I 2025-05-02 11:26:11,228] Trial 8 finished with value: 0.9431872037914693 and parameters: {'max_depth': 30, 'min_samples_split': 6, 'min_samples_leaf': 4, 'criterion': 'gini'}. Best is trial 8 with value: 0.9431872037914693.
# [I 2025-05-02 11:26:11,742] Trial 9 finished with value: 0.9268364928909951 and parameters: {'max_depth': 6, 'min_samples_split': 16, 'min_samples_leaf': 10, 'criterion': 'entropy'}. Best is trial 8 with value: 0.9431872037914693.
# [I 2025-05-02 11:26:12,503] Trial 10 finished with value: 0.9438388625592417 and parameters: {'max_depth': 19, 'min_samples_split': 6, 'min_samples_leaf': 5, 'criterion': 'gini'}. Best is trial 10 with value: 0.9438388625592417.
# [I 2025-05-02 11:26:13,258] Trial 11 finished with value: 0.9429502369668246 and parameters: {'max_depth': 20, 'min_samples_split': 6, 'min_samples_leaf': 5, 'criterion': 'gini'}. Best is trial 10 with value: 0.9438388625592417.
# [I 2025-05-02 11:26:14,028] Trial 12 finished with value: 0.9438388625592417 and parameters: {'max_depth': 19, 'min_samples_split': 5, 'min_samples_leaf': 5, 'criterion': 'gini'}. Best is trial 10 with value: 0.9438388625592417.
# [I 2025-05-02 11:26:14,797] Trial 13 finished with value: 0.9418838862559242 and parameters: {'max_depth': 19, 'min_samples_split': 4, 'min_samples_leaf': 6, 'criterion': 'gini'}. Best is trial 10 with value: 0.9438388625592417.
# [I 2025-05-02 11:26:15,566] Trial 14 finished with value: 0.9436018957345972 and parameters: {'max_depth': 18, 'min_samples_split': 9, 'min_samples_leaf': 5, 'criterion': 'gini'}. Best is trial 10 with value: 0.9438388625592417.
# [I 2025-05-02 11:26:16,332] Trial 15 finished with value: 0.9422393364928909 and parameters: {'max_depth': 22, 'min_samples_split': 9, 'min_samples_leaf': 6, 'criterion': 'gini'}. Best is trial 10 with value: 0.9438388625592417.
# [I 2025-05-02 11:26:17,100] Trial 16 finished with value: 0.9438981042654028 and parameters: {'max_depth': 16, 'min_samples_split': 4, 'min_samples_leaf': 4, 'criterion': 'gini'}. Best is trial 16 with value: 0.9438981042654028.
# [I 2025-05-02 11:26:17,871] Trial 17 finished with value: 0.9468009478672986 and parameters: {'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 3, 'criterion': 'gini'}. Best is trial 17 with value: 0.9468009478672986.
# [I 2025-05-02 11:26:18,524] Trial 18 finished with value: 0.9418838862559241 and parameters: {'max_depth': 10, 'min_samples_split': 3, 'min_samples_leaf': 3, 'criterion': 'gini'}. Best is trial 17 with value: 0.9468009478672986.
# [I 2025-05-02 11:26:19,292] Trial 19 finished with value: 0.953850710900474 and parameters: {'max_depth': 15, 'min_samples_split': 12, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 19 with value: 0.953850710900474.
# [I 2025-05-02 11:26:20,380] Trial 20 finished with value: 0.9507701421800947 and parameters: {'max_depth': 13, 'min_samples_split': 12, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 19 with value: 0.953850710900474.
# [I 2025-05-02 11:26:21,530] Trial 21 finished with value: 0.9507701421800947 and parameters: {'max_depth': 13, 'min_samples_split': 12, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 19 with value: 0.953850710900474.
# [I 2025-05-02 11:26:22,419] Trial 22 finished with value: 0.9507701421800947 and parameters: {'max_depth': 13, 'min_samples_split': 12, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 19 with value: 0.953850710900474.
# [I 2025-05-02 11:26:23,030] Trial 23 finished with value: 0.9401658767772512 and parameters: {'max_depth': 8, 'min_samples_split': 15, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 19 with value: 0.953850710900474.
# [I 2025-05-02 11:26:23,744] Trial 24 finished with value: 0.9456753554502371 and parameters: {'max_depth': 12, 'min_samples_split': 13, 'min_samples_leaf': 2, 'criterion': 'gini'}. Best is trial 19 with value: 0.953850710900474.
# [I 2025-05-02 11:26:24,417] Trial 25 finished with value: 0.9427725118483412 and parameters: {'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 2, 'criterion': 'gini'}. Best is trial 19 with value: 0.953850710900474.
# [I 2025-05-02 11:26:25,184] Trial 26 finished with value: 0.9531398104265403 and parameters: {'max_depth': 14, 'min_samples_split': 11, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 19 with value: 0.953850710900474.
# [I 2025-05-02 11:26:25,641] Trial 27 finished with value: 0.915462085308057 and parameters: {'max_depth': 5, 'min_samples_split': 18, 'min_samples_leaf': 2, 'criterion': 'gini'}. Best is trial 19 with value: 0.953850710900474.
# [I 2025-05-02 11:26:26,451] Trial 28 finished with value: 0.9550355450236967 and parameters: {'max_depth': 16, 'min_samples_split': 11, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 28 with value: 0.9550355450236967.
# [I 2025-05-02 11:26:27,265] Trial 29 finished with value: 0.9416469194312796 and parameters: {'max_depth': 24, 'min_samples_split': 19, 'min_samples_leaf': 3, 'criterion': 'gini'}. Best is trial 28 with value: 0.9550355450236967.
# [I 2025-05-02 11:26:28,053] Trial 30 finished with value: 0.9499407582938388 and parameters: {'max_depth': 16, 'min_samples_split': 10, 'min_samples_leaf': 2, 'criterion': 'gini'}. Best is trial 28 with value: 0.9550355450236967.
# [I 2025-05-02 11:26:28,752] Trial 31 finished with value: 0.9453791469194313 and parameters: {'max_depth': 11, 'min_samples_split': 11, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 28 with value: 0.9550355450236967.
# [I 2025-05-02 11:26:29,521] Trial 32 finished with value: 0.951303317535545 and parameters: {'max_depth': 14, 'min_samples_split': 14, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 28 with value: 0.9550355450236967.
# [I 2025-05-02 11:26:30,322] Trial 33 finished with value: 0.9485189573459716 and parameters: {'max_depth': 17, 'min_samples_split': 15, 'min_samples_leaf': 2, 'criterion': 'gini'}. Best is trial 28 with value: 0.9550355450236967.
# [I 2025-05-02 11:26:31,089] Trial 34 finished with value: 0.951303317535545 and parameters: {'max_depth': 14, 'min_samples_split': 14, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 28 with value: 0.9550355450236967.
# [I 2025-05-02 11:26:31,851] Trial 35 finished with value: 0.9520734597156398 and parameters: {'max_depth': 22, 'min_samples_split': 8, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 28 with value: 0.9550355450236967.
# [I 2025-05-02 11:26:32,966] Trial 36 finished with value: 0.9473341232227487 and parameters: {'max_depth': 23, 'min_samples_split': 8, 'min_samples_leaf': 2, 'criterion': 'entropy'}. Best is trial 28 with value: 0.9550355450236967.
# [I 2025-05-02 11:26:34,103] Trial 37 finished with value: 0.9420023696682464 and parameters: {'max_depth': 21, 'min_samples_split': 8, 'min_samples_leaf': 4, 'criterion': 'entropy'}. Best is trial 28 with value: 0.9550355450236967.
# [I 2025-05-02 11:26:34,972] Trial 38 finished with value: 0.9449052132701421 and parameters: {'max_depth': 26, 'min_samples_split': 10, 'min_samples_leaf': 2, 'criterion': 'entropy'}. Best is trial 28 with value: 0.9550355450236967.
# [I 2025-05-02 11:26:35,709] Trial 39 finished with value: 0.9427725118483412 and parameters: {'max_depth': 17, 'min_samples_split': 11, 'min_samples_leaf': 3, 'criterion': 'entropy'}. Best is trial 28 with value: 0.9550355450236967.
# [I 2025-05-02 11:26:36,410] Trial 40 finished with value: 0.9364928909952607 and parameters: {'max_depth': 26, 'min_samples_split': 8, 'min_samples_leaf': 8, 'criterion': 'entropy'}. Best is trial 28 with value: 0.9550355450236967.
# [I 2025-05-02 11:26:37,143] Trial 41 finished with value: 0.9453791469194313 and parameters: {'max_depth': 14, 'min_samples_split': 13, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 28 with value: 0.9550355450236967.
# [I 2025-05-02 11:26:37,868] Trial 42 finished with value: 0.9421208530805687 and parameters: {'max_depth': 12, 'min_samples_split': 14, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 28 with value: 0.9550355450236967.
# [I 2025-05-02 11:26:38,648] Trial 43 finished with value: 0.9510071090047394 and parameters: {'max_depth': 15, 'min_samples_split': 17, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 28 with value: 0.9550355450236967.
# [I 2025-05-02 11:26:39,349] Trial 44 finished with value: 0.9424763033175356 and parameters: {'max_depth': 11, 'min_samples_split': 13, 'min_samples_leaf': 2, 'criterion': 'gini'}. Best is trial 28 with value: 0.9550355450236967.
# [I 2025-05-02 11:26:40,072] Trial 45 finished with value: 0.9463270142180095 and parameters: {'max_depth': 14, 'min_samples_split': 11, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 28 with value: 0.9550355450236967.
# [I 2025-05-02 11:26:40,899] Trial 46 finished with value: 0.9485189573459716 and parameters: {'max_depth': 17, 'min_samples_split': 15, 'min_samples_leaf': 2, 'criterion': 'gini'}. Best is trial 28 with value: 0.9550355450236967.
# [I 2025-05-02 11:26:41,737] Trial 47 finished with value: 0.9465047393364928 and parameters: {'max_depth': 21, 'min_samples_split': 7, 'min_samples_leaf': 3, 'criterion': 'gini'}. Best is trial 28 with value: 0.9550355450236967.
# [I 2025-05-02 11:26:42,418] Trial 48 finished with value: 0.94010663507109 and parameters: {'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 28 with value: 0.9550355450236967.
# [I 2025-05-02 11:26:43,074] Trial 49 finished with value: 0.9387440758293838 and parameters: {'max_depth': 9, 'min_samples_split': 13, 'min_samples_leaf': 7, 'criterion': 'gini'}. Best is trial 28 with value: 0.9550355450236967.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Yield: Actual vs Predicted
plt.figure(figsize=(6, 6))
sns.scatterplot(x=y_yield_test, y=yield_pred, color='green')
plt.plot([y_yield_test.min(), y_yield_test.max()],
         [y_yield_test.min(), y_yield_test.max()], 'r--')
plt.xlabel('Actual Yield')
plt.ylabel('Predicted Yield')
plt.title('Yield: Actual vs Predicted')
plt.grid(True)
plt.show()

# Price: Actual vs Predicted
plt.figure(figsize=(6, 6))
sns.scatterplot(x=y_price_test, y=price_pred, color='blue')
plt.plot([y_price_test.min(), y_price_test.max()],
         [y_price_test.min(), y_price_test.max()], 'r--')
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Price: Actual vs Predicted')
plt.grid(True)
plt.show()

# %%
def plot_feature_importance(model, feature_names, title, top_n=10):
    importances = model.feature_importances_
    indices = importances.argsort()[-top_n:]
    plt.figure(figsize=(8, 6))
    plt.barh(range(len(indices)), importances[indices], color='skyblue')
    plt.yticks(range(len(indices)), [feature_names[i] for i in indices])
    plt.title(f'Feature Importance - {title}')
    plt.xlabel('Importance Score')
    plt.tight_layout()
    plt.show()

# Feature names
feature_names = X_train.columns if hasattr(X_train, 'columns') else [f'feature_{i}' for i in range(X_train.shape[1])]

# Plot
plot_feature_importance(yield_model, feature_names, "Yield")
plot_feature_importance(price_model, feature_names, "Price")
plot_feature_importance(crop_model, feature_names, "Crop Type")

# %%
# Finalized ML Pipeline with Best Models for Yield, Price, and Crop Type using GridSearchCV

from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import r2_score, accuracy_score
import logging

logger = logging.getLogger()

# Split
data_split = train_test_split(X, y_yield, y_price, y_crop, test_size=0.2, random_state=42)
X_train, X_test, y_yield_train, y_yield_test, y_price_train, y_price_test, y_crop_train, y_crop_test = data_split

# ---------------------------- GRID SEARCH CV ----------------------------

# Yield Model - RandomForestRegressor
param_grid_yield = {
    'n_estimators': [100, 200, 300],
    'max_depth': [10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'max_features': ['sqrt', 'log2', None],
    'random_state': [42],
    'n_jobs': [-1]
}
yield_model = GridSearchCV(RandomForestRegressor(), param_grid_yield, cv=5, scoring='r2', n_jobs=-1)
yield_model.fit(X_train, y_yield_train)
yield_pred = yield_model.predict(X_test)
yield_r2 = r2_score(y_yield_test, yield_pred)
logger.info(f"Best RF Parameters (Yield): {yield_model.best_params_}")
logger.info(f"Tuned Yield R2: {yield_r2:.2f}")

# Price Model - RandomForestRegressor
param_grid_price = {
    'n_estimators': [100, 200, 300],
    'max_depth': [10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'max_features': ['sqrt', 'log2', None],
    'random_state': [42],
    'n_jobs': [-1]
}
price_model = GridSearchCV(RandomForestRegressor(), param_grid_price, cv=5, scoring='r2', n_jobs=-1)
price_model.fit(X_train, y_price_train)
price_pred = price_model.predict(X_test)
price_r2 = r2_score(y_price_test, price_pred)
logger.info(f"Best RF Parameters (Price): {price_model.best_params_}")
logger.info(f"Tuned Price R2: {price_r2:.2f}")

# Crop Model - DecisionTreeClassifier
param_grid_crop = {
    'max_depth': [3, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'criterion': ['gini', 'entropy'],
    'random_state': [42]
}
crop_model = GridSearchCV(DecisionTreeClassifier(), param_grid_crop, cv=5, scoring='accuracy', n_jobs=-1)
crop_model.fit(X_train, y_crop_train)
crop_pred = crop_model.predict(X_test)
crop_accuracy = accuracy_score(y_crop_test, crop_pred)
logger.info(f"Best DT Parameters (Crop): {crop_model.best_params_}")
logger.info(f"Tuned Crop Accuracy: {crop_accuracy:.2f}")

# %%
# Finalized ML Pipeline with Best Models for Yield, Price, and Crop Type using RandomizedSearchCV and GridSearchCV Hybrid

from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV
from sklearn.metrics import r2_score, accuracy_score
from scipy.stats import randint as sp_randint
from scipy.stats import uniform
import logging

logger = logging.getLogger()

# Split
data_split = train_test_split(X, y_yield, y_price, y_crop, test_size=0.2, random_state=42)
X_train, X_test, y_yield_train, y_yield_test, y_price_train, y_price_test, y_crop_train, y_crop_test = data_split

# ---------------------------- RANDOMIZED + GRID SEARCH CV ----------------------------

# Yield Model - RandomForestRegressor
param_dist_yield = {
    'n_estimators': sp_randint(100, 500),
    'max_depth': sp_randint(10, 50),
    'min_samples_split': sp_randint(2, 20),
    'max_features': ['sqrt', 'log2', None]
}
yield_random_search = RandomizedSearchCV(RandomForestRegressor(random_state=42, n_jobs=-1), param_distributions=param_dist_yield, n_iter=30, cv=5, scoring='r2', n_jobs=-1, random_state=42)
yield_random_search.fit(X_train, y_yield_train)
yield_pred = yield_random_search.predict(X_test)
yield_r2 = r2_score(y_yield_test, yield_pred)
logger.info(f"Best RF Parameters (Yield): {yield_random_search.best_params_}")
logger.info(f"Tuned Yield R2: {yield_r2:.2f}")

# Price Model - RandomForestRegressor
param_dist_price = {
    'n_estimators': sp_randint(100, 500),
    'max_depth': sp_randint(10, 50),
    'min_samples_split': sp_randint(2, 20),
    'max_features': ['sqrt', 'log2', None]
}
price_random_search = RandomizedSearchCV(RandomForestRegressor(random_state=42, n_jobs=-1), param_distributions=param_dist_price, n_iter=30, cv=5, scoring='r2', n_jobs=-1, random_state=42)
price_random_search.fit(X_train, y_price_train)
price_pred = price_random_search.predict(X_test)
price_r2 = r2_score(y_price_test, price_pred)
logger.info(f"Best RF Parameters (Price): {price_random_search.best_params_}")
logger.info(f"Tuned Price R2: {price_r2:.2f}")

# Crop Model - DecisionTreeClassifier
param_dist_crop = {
    'max_depth': sp_randint(5, 30),
    'min_samples_split': sp_randint(2, 20),
    'min_samples_leaf': sp_randint(1, 10),
    'criterion': ['gini', 'entropy']
}
crop_random_search = RandomizedSearchCV(DecisionTreeClassifier(random_state=42), param_distributions=param_dist_crop, n_iter=30, cv=5, scoring='accuracy', n_jobs=-1, random_state=42)
crop_random_search.fit(X_train, y_crop_train)
crop_pred = crop_random_search.predict(X_test)
crop_accuracy = accuracy_score(y_crop_test, crop_pred)
logger.info(f"Best DT Parameters (Crop): {crop_random_search.best_params_}")
logger.info(f"Tuned Crop Accuracy: {crop_accuracy:.2f}")
